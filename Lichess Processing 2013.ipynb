# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nashpy as nash
import itertools
import cvxpy as cp
import cvxopt
from tqdm import tqdm
import seaborn as sb
from scipy.stats import skewnorm
from scipy.optimize import minimize
import pickle

# %%
# Fill in missing based on elo ratings
def win_rate_elo(elo1, elo2, alpha = np.log(10)/400):
    """
    Computes win rate of player 1 to player 2 given their elo ratings
    """
    return 1 / (1 + np.exp(-alpha * (elo1 - elo2)))

# %%
df = pd.read_csv('Data/2013/2013_2.csv')

# %%
df.head()
# Out:
#       White         Black Result WhiteElo BlackElo
# 0   madkupe  zhorik_kapov    1-0     1366     1223
# 1  Elquesoy      sani5057    1-0     1477     1716
# 2   genicio           Kol    0-1     1623     1794
# 3     Sa052      FelipeCP    0-1     1817     1948
# 4    bjagus  pseudoknight    0-1     1687     1758

# %%
df = df.rename(columns = {'White': 'white_player', 'Black': 'black_player', 'Result':'result',
                         'WhiteElo': 'white_elo', 'BlackElo':'black_elo'})

df.head()
# Out:
#   white_player  black_player result white_elo black_elo
# 0      madkupe  zhorik_kapov    1-0      1366      1223
# 1     Elquesoy      sani5057    1-0      1477      1716
# 2      genicio           Kol    0-1      1623      1794
# 3        Sa052      FelipeCP    0-1      1817      1948
# 4       bjagus  pseudoknight    0-1      1687      1758

# %%
df[df['result'] == '*']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %%
possible_results = ['0-1', '1-0', '1/2-1/2']
drop_idx = df[~df['result'].isin(possible_results)].index
df = df.drop(drop_idx)

df[df['result'] == '*']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %% [markdown]
# Drop unknown elo ratings

# %%
drop_idx = df[df['white_elo'] == '?'].index
df = df.drop(drop_idx)

df[df['white_elo'] == '?']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %%
drop_idx = df[df['black_elo'] == '?'].index
df = df.drop(drop_idx)

df[df['black_elo'] == '?']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %%
# Convert to win-draw-lose
df.loc[df['result'] == '0-1', 'result'] = -1
df.loc[df['result'] == '1-0', 'result'] = 1
df.loc[df['result'] == '1/2-1/2', 'result'] = 0

# %%
# Convert ratings to integers
df['white_elo'] = np.array(df['white_elo']).astype('int64')
df['black_elo'] = np.array(df['black_elo']).astype('int64')

# %%
white_elos = np.array(df['white_elo'])
black_elos = np.array(df['black_elo'])

# %%
plt.title('White Elo Histogram')
plt.hist(white_elos)
# Out:
# (array([1.21500e+03, 1.34740e+04, 8.45560e+04, 2.92507e+05, 4.88414e+05,
#         3.75087e+05, 1.40438e+05, 3.57390e+04, 4.21600e+03, 7.50000e+01]),
#  array([ 758.,  940., 1122., 1304., 1486., 1668., 1850., 2032., 2214.,
#         2396., 2578.]),
#  <BarContainer object of 10 artists>)

# %%
plt.title('Black Elo Histogram')
plt.hist(black_elos)
# Out:
# (array([1.30000e+03, 1.47540e+04, 8.72000e+04, 2.81470e+05, 4.90723e+05,
#         3.68121e+05, 1.46264e+05, 4.05480e+04, 5.24100e+03, 1.00000e+02]),
#  array([ 735. ,  919.1, 1103.2, 1287.3, 1471.4, 1655.5, 1839.6, 2023.7,
#         2207.8, 2391.9, 2576. ]),
#  <BarContainer object of 10 artists>)

# %%
white_ratings, counts = np.unique(white_elos, return_counts = True)
black_ratings, counts = np.unique(black_elos, return_counts = True)

# %%
white_min = np.min(white_elos); white_max = np.max(white_elos)
black_min = np.min(black_elos); black_max = np.max(black_elos)

print(f"For white, min = {white_min}, max = {white_max}")
print(f"For black, min = {black_min}, max = {black_max}")

# Bounds should be the 'loose' one. Might want to cut down in case there's no matchups
lb = min(white_min, black_min); ub = max(white_max, black_max)
print(f"Bins range {lb} - {ub}")
# Out:
# For white, min = 758, max = 2578
# For black, min = 735, max = 2576
# Bins range 735 - 2578

# %% [markdown]
# ## Creating the payoffs
#
# ### Method 1: Sample uniformly n-bins from the range above, and average the win rate. Win counts for +1, loss -1, draw 0

# %%
def create_bins(lower_bound, upper_bound, n):
    width = (upper_bound - lower_bound) / n
    
    ub = lower_bound + width; lb = lower_bound; bins = [(lb, ub)]
    for _ in range(n-1):
        lb += width; ub += width; bins.append((lb, ub))
    
    return bins

def within(bin_range, num):
    return num >= bin_range[0] and num < bin_range[1]

# %%
# Check if data contains lower ratings beating greater ratings
sieve_greater = (df['white_elo'] <= df['black_elo']) & (df['result'] >= 0)
df[sieve_greater]
# Out:
#         game_id    type result   white_player  black_player  white_elo  \
# Index
# 1      WagNiFfQ   Blitz      0         batyko  ahli_blunder       1826
# 20     AAYKnWvt  Bullet      1   KingofKings7     alico1903       2046
# 25     7da3nkeh  Bullet      1        hshisug      Vperezgm       1887
# 26     M0Sl5CVI   Rapid      1           RRSR     jvmaximus       1903
# 38     EuGDHldp  Bullet      1  super-code_ru     Misilleme        800
# ...         ...     ...    ...            ...           ...        ...
# 15961  h8VdqGR9  Bullet      1  AUSTIN_PRINCE         kligs       1447
# 15962  doApPb6F   Blitz      1           zx14     KadrinEfe       1297
# 15965  PKRUE0x0   Rapid      1      panscrub5     vezir_mat       1672
# 15974  IWrb8b44   Blitz      1       flanky64         Bur54       1302
# 15977  Ery4GsZJ   Blitz      1      TemurAziz        KEDMNU       1389
#
#        black_elo
# Index
# 1           1826
# 20          2127
# 25          1924
# 26          1930
# 38           872
# ...          ...
# 15961       1461
# 15962       1308
# 15965       1672
# 15974       1304
# 15977       1500
#
# [45802 rows x 7 columns]

# %%
# Check if data contains lower ratings beating greater ratings
sieve_greater = (df['black_elo'] <= df['white_elo']) & (df['result'] <= 0)
df[sieve_greater]
# Out:
#         game_id    type result       white_player   black_player  white_elo  \
# Index
# 0      mAEz2AcC   Rapid     -1          AliKhaled        ifospor       1702
# 1      WagNiFfQ   Blitz      0             batyko   ahli_blunder       1826
# 8      Tr8HhqHt   Blitz     -1              BMWX5     nistvana83       1941
# 9      53OXpsTy  Bullet     -1           Vperezgm     Telesforus       1935
# 10     fHwNFnEm   Blitz     -1            ahhatip        inalcik       1133
# ...         ...     ...    ...                ...            ...        ...
# 15950  Bc0MxCBM  Bullet     -1  anton1dalnikovich      Pravin171       1409
# 15955  3dslmEH7   Blitz     -1          forrest92  Veter-Peremen       1863
# 15963  vuDze9mH   Blitz     -1          Stock2020   Pavlodar_pvl       2165
# 15976  CJGHaez8   Blitz     -1        gungorkeles        Nicozxc       1589
# 15978  ccZJzA45   Blitz     -1            Pvp9897    fatemeh1375       1239
#
#        black_elo
# Index
# 0           1628
# 1           1826
# 8           1894
# 9           1921
# 10           944
# ...          ...
# 15950       1396
# 15955       1837
# 15963       2165
# 15976       1562
# 15978       1182
#
# [42619 rows x 7 columns]

# %%
wlb, wub = (1829, 1832); blb, bub = (2001, 2003)

# %%
sieve_w = (df['white_elo'] < wub) & (df['white_elo'] > wlb)
df_sieve_w = df[sieve_w]
df_sieve_w['black_elo'].unique()
# Out:
# array([1792, 1841, 1983, 1805, 1925, 1763, 1751, 1778, 1872, 1721, 1756,
#        1881, 1620, 1724, 1842, 2104, 1704, 1829, 1830, 1803, 1781, 1686,
#        1557, 1573, 1546, 2013, 1959, 1860, 1806, 1956, 1862, 1657, 1764,
#        2078, 1838, 1749, 1865, 1766, 1699, 1583, 1691, 1807, 1825, 1740,
#        1797, 1750, 1722, 1934, 2012, 2034, 1891, 1843, 1637, 1826, 1905,
#        1820, 1676, 1856, 1895, 1747, 1606, 1898, 1782, 1965, 1730, 1821,
#        1818, 1684, 2056, 1801, 2004, 1789, 1998, 1920, 2207, 1811, 2015,
#        1668, 1828, 1526, 1773, 1834, 1744, 1732, 2049, 2062, 1835, 2046,
#        1688, 1927, 2020, 1815, 1709, 1824, 1919, 1693, 1772, 1816, 1975,
#        1878, 1879, 1485, 1893, 1753, 1864, 1804, 1532, 1587, 1836, 1802,
#        1888, 1664, 1913, 1831, 1736, 1882, 1832, 2080, 1787, 1798, 1729,
#        1850, 1977, 1746, 1989, 1840, 1450, 1775, 1774, 1972, 1997, 1706,
#        2433, 1790, 2018, 1745, 2447, 1930, 2146, 1839, 1886, 1757, 1851,
#        1896, 1921, 1786, 1917, 1863, 2245, 1735, 1855, 1915, 1785, 1914,
#        1903, 1780, 1955, 1796, 2112, 1813, 1769, 1810, 1852, 1812, 1932,
#        1887, 1845, 1822, 1349, 2124, 1793, 2061, 1854, 1848, 1714, 1936,
#        1897, 1765, 1833, 2009, 1727, 2308, 1784, 1791, 1900, 1795, 1817,
#        1847, 2135, 1937, 1758, 1869, 1868, 1809, 2002, 1468, 1397, 1644,
#        1837, 1814, 1904], dtype=int64)

# %%
# Functions
def create_payoff(n, bin_lb, bin_ub):
    # Construct payoff template and bins
    # Also returns marker array, to indicate whether one missing, both missing, or none missing
    bins = np.array(create_bins(bin_lb, bin_ub, n))
    payoff = np.ones((n, n)) * -8; np.fill_diagonal(payoff, 0)
    
    # Marker matrix to indicate missing data. 1 for both present, -1 for p1 white, -2 for p1 black, -3 for both series
    mat = np.zeros((n, n))
    
    for i in tqdm(range(len(bins))):
        for j in range(len(bins)):
           # These are actually p1 and p2 ratings. We want to find where this p1 rating is white vs p2 black and
            # then vice versa
            p1_bin_lb, p1_bin_ub = bins[i]
            p2_bin_lb, p2_bin_ub = bins[j] 
            
            # Mid-bin rating to predict if missing
            p1_rating = (p1_bin_ub + p1_bin_lb) / 2
            p2_rating = (p2_bin_ub + p2_bin_lb) / 2
            
            if p1_bin_lb >= p2_bin_lb:
                continue
            else:
                # Sieve off data
                p1_white = (df['white_elo'] < p1_bin_ub) & (df['white_elo'] >= p1_bin_lb)
                p2_white = (df['white_elo'] < p2_bin_ub) & (df['white_elo'] >= p2_bin_lb)

                p1_black = (df['black_elo'] < p1_bin_ub) & (df['black_elo'] >= p1_bin_lb)
                p2_black = (df['black_elo'] < p2_bin_ub) & (df['black_elo'] >= p2_bin_lb)

                # Count data available
                p1_white_counts = np.sum(p1_white); p1_black_counts = np.sum(p1_black)
                p2_white_counts = np.sum(p2_white); p2_black_counts = np.sum(p2_black)

                # bool_ser1 = p1 white and p2 black; bool_ser2 = p1 black and p2 white
                bool_ser1 = p1_white & p2_black; bool_ser2 = p1_black & p2_white
                ser1_count = np.sum(bool_ser1); ser2_count = np.sum(bool_ser2)

                if ser1_count != 0 and ser2_count != 0:
                    # Both matchups exist in data
                    # To get average, must put a - b, since if black wins, result is -1. Payoff matrix
                    # is wrt to player 1
                    value = (np.mean(df[bool_ser1]['result']) - np.mean(df[bool_ser2]['result'])) / 2
                    payoff[i,j] = value
                    payoff[j,i] = -value
                    mat[i,j] = 1; mat[j,i] = 1
                else:
                    if ser1_count !=0 and ser2_count == 0:
                        # i.e. series 2 matchup don't exist. Hence series 1 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 2 missing")
                        ser1_rate = np.mean(df[bool_ser1]['result'])

                        # Predict series 2 with elo. This don't care who is white/black
                        # NOTE: win probability is probability of player 1 winning, yielding a reward of +1
                        # To find expected score, must multiply probability with score
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser2_rate = win_prob * 1 + (1 - win_prob) * -1
                
                        value = (ser1_rate + ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -2
                        mat[j,i] = -2

                    if ser1_count == 0 and ser2_count != 0:
                        # i.e. series 1 matchup don't exist. Hence series 2 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 1 missing")
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser1_rate = win_prob * 1 + (1 - win_prob) * -1
                        ser2_rate = np.mean(df[bool_ser2]['result'])
                        value = (ser1_rate - ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -1; mat[j,i] = -1

                    if ser1_count == 0 and ser2_count == 0:
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, both missing")
                        # i.e. both are missing, predict using elo
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        value = win_prob * 1 + (1 - win_prob) * (-1)
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -3; mat[j,i] = -3
                        
    return payoff, mat


def create_payoff_2(white_bins, black_bins):
    # Construct payoff template and bins
    # Also returns marker array, to indicate whether one missing, both missing, or none missing
    n_row = len(white_bins); n_col = len(black_bins)
    payoff = np.ones((n_row, n_col)) * -8; np.fill_diagonal(payoff, 0)
    
    # Marker matrix to indicate missing data. 1 for both present, -1 for p1 white, -2 for p1 black, -3 for both series
    mat = np.zeros((n_row, n_col))
    
    for i in tqdm(range(n_row)):
        for j in range(range(n_col)):
           # These are actually p1 and p2 ratings. We want to find where this p1 rating is white vs p2 black and
            # then vice versa
            p1_bin_lb, p1_bin_ub = white_bins[i]
            p2_bin_lb, p2_bin_ub = black_bins[j]
            
            # Mid-bin rating to predict if missing
            p1_rating = (p1_bin_ub + p1_bin_lb) / 2
            p2_rating = (p2_bin_ub + p2_bin_lb) / 2
            
            if p1_bin_lb >= p2_bin_lb:
                continue
            else:
                # Sieve off data
                p1_white = (df['white_elo'] < p1_bin_ub) & (df['white_elo'] >= p1_bin_lb)
                p2_white = (df['white_elo'] < p2_bin_ub) & (df['white_elo'] >= p2_bin_lb)

                p1_black = (df['black_elo'] < p1_bin_ub) & (df['black_elo'] >= p1_bin_lb)
                p2_black = (df['black_elo'] < p2_bin_ub) & (df['black_elo'] >= p2_bin_lb)

                # Count data available
                p1_white_counts = np.sum(p1_white); p1_black_counts = np.sum(p1_black)
                p2_white_counts = np.sum(p2_white); p2_black_counts = np.sum(p2_black)

                # bool_ser1 = p1 white and p2 black; bool_ser2 = p1 black and p2 white
                bool_ser1 = p1_white & p2_black; bool_ser2 = p1_black & p2_white
                ser1_count = np.sum(bool_ser1); ser2_count = np.sum(bool_ser2)

                if ser1_count != 0 and ser2_count != 0:
                    # Both matchups exist in data
                    # To get average, must put a - b, since if black wins, result is -1. Payoff matrix
                    # is wrt to player 1
                    value = (np.mean(df[bool_ser1]['result']) - np.mean(df[bool_ser2]['result'])) / 2
                    payoff[i,j] = value
                    payoff[j,i] = -value
                    mat[i,j] = 1; mat[j,i] = 1
                else:
                    if ser1_count !=0 and ser2_count == 0:
                        # i.e. series 2 matchup don't exist. Hence series 1 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 2 missing")
                        ser1_rate = np.mean(df[bool_ser1]['result'])

                        # Predict series 2 with elo. This don't care who is white/black
                        # NOTE: win probability is probability of player 1 winning, yielding a reward of +1
                        # To find expected score, must multiply probability with score
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser2_rate = win_prob * 1 + (1 - win_prob) * -1
                
                        value = (ser1_rate + ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -2
                        mat[j,i] = -2

                    if ser1_count == 0 and ser2_count != 0:
                        # i.e. series 1 matchup don't exist. Hence series 2 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 1 missing")
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser1_rate = win_prob * 1 + (1 - win_prob) * -1
                        ser2_rate = np.mean(df[bool_ser2]['result'])
                        value = (ser1_rate - ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -1; mat[j,i] = -1

                    if ser1_count == 0 and ser2_count == 0:
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, both missing")
                        # i.e. both are missing, predict using elo
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        value = win_prob * 1 + (1 - win_prob) * (-1)
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -3; mat[j,i] = -3
                        
    return payoff, mat
            
class NashCluster():
    
    def __init__(self, strat_payoffs, ori_idx, pvect):
        self.size = strat_payoffs.shape[0]
        self.payoffs = strat_payoffs
        self.strat_idx = ori_idx
        self.probability = pvect
        
    def computeRPS(self):
        return None
    
def solve_MaxEnt_NE(payoff, verbose = False, eps = 1e-5, zero_tol = 1e-6, iters = 500, cycle = 5):
    
    init_val = np.random.uniform(size = payoff.shape[0])
    init_val = init_val / np.sum(init_val)
    
    p = cp.Variable(payoff.shape[0], value = init_val)
    constraints = [payoff @ p <= 0, cp.sum(p) == 1, p >= 0]
    objective = cp.sum(cp.entr(p))
    prob = cp.Problem(cp.Maximize(objective), constraints)
    
    try:
      cycle_count = 0; done = False
      while cycle_count < cycle and done is False:
        prob.solve(verbose = verbose, solver = cp.MOSEK, warm_start = True)
        p_vect = p.value * (p.value > zero_tol)
        diff = payoff @ p_vect.reshape(-1, 1)
        print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
        done = True if np.sum(diff >= eps) == 0 else False
        cycle_count += 1
    except cp.SolverError:
      print("MOSEK FAILED?")
      try:
        # Try ECOS_BB first
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = 1000, solver = cp.ECOS_BB, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
          print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
      except cp.SolverError:
        print("ECOS_BB FAILED")
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = iters, solver = cp.SCS, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
          print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
  
    # Clean - small values
    p_vect = p_vect * (p_vect > zero_tol)
    return p_vect, np.sum(diff>=eps)
    
def Nash_Clustering(payoff, marker, algo = "cvx", eps = 1e-4, zero_tol = 1e-8):
    n_strat = payoff.shape[0]; counter = 0;

    # This is the remaining payoff and the remaining strategy indexes
    curr_payoff = payoff; curr_remaining = np.arange(n_strat); curr_marker = marker
    nash_clusters = []; unsolved_cases = []; marker_instances = []

    while n_strat > 1: # if only 1 strategy remaining, this itself is the nash cluster
        print(f"Iteration {counter}")

        # # Compute the NE supports. Lemke Howson seems the fastest
        # game = nash.Game(curr_payoff + np.eye(curr_payoff.shape[0]) * 1e-10)
        # if algo == "Lemke":
        #     nash_eqs = game.lemke_howson_enumeration()
        #     nash_eq = np.array(next(nash_eqs)[0])

        # if algo == 'Support': # slow because enumerates all possible NE supports
        #     nash_eqs = game.support_enumeration()
        #     nash_eq = np.array(next(nash_eqs)[0])

        # if algo == 'Vertex':
        #     nash_eqs = game.vertex_enumeration()
        #     nash_eq = np.array(next(nash_eqs)[0])

        if algo == 'cvx': # solve using cvxpy, seems to be the only one working for now
            nash_eq, diff = solve_MaxEnt_NE(curr_payoff, eps =1e-4, zero_tol = zero_tol, iters = int(2e4), cycle = 5)
            print(f"Outside, diff = {diff}")
            p_vect = nash_eq[nash_eq >= zero_tol]
#             if diff > -10:
#               print("APPENDING UNSOLVED CASE")
#               unsolved_cases.append(curr_payoff)
#               marker_instances.append(curr_marker)

        # Take the supports, exclude them in the next round payoffs
        taken_strat = np.where(nash_eq >= zero_tol)[0]; remaining_strat = np.where(nash_eq < zero_tol)[0]
        
        if len(taken_strat) != len(p_vect):
            print("WTF")
            print(taken_strat, p_vect)
        taken_idx = np.array(list(itertools.product(taken_strat, repeat = 2)))
        remaining_idx = np.array(list(itertools.product(remaining_strat, repeat = 2)))

        strat_payoffs = payoff[taken_idx[:,0], taken_idx[:, 1]].reshape(taken_strat.shape[0], taken_strat.shape[0])
        nash_clusters.append(NashCluster(strat_payoffs, curr_remaining[taken_strat], p_vect))

        # Get the remaining payoff. If statement here to prevent cases when remaining_idx is empty and [:,0] wont work
        if len(remaining_strat) > 0:
          curr_payoff = curr_payoff[remaining_idx[:,0], remaining_idx[:,1]].reshape(remaining_strat.shape[0], remaining_strat.shape[0])
          curr_remaining = curr_remaining[remaining_strat]
          curr_marker = curr_marker[remaining_idx[:,0], remaining_idx[:,1]].reshape(remaining_strat.shape[0], remaining_strat.shape[0])

        n_strat -= strat_payoffs.shape[0]

        counter += 1
        print(f"Strategies left {n_strat}")
        print(f"Payoff remaining size {curr_payoff.shape[0]}") 

    if n_strat == 1:
        nash_clusters.append(NashCluster(curr_payoff, curr_remaining, np.array([1])))

    return nash_clusters, marker_instances, unsolved_cases

def plot_results(nash_clusters, title):
  nc_sizes = []
  for nc in nash_clusters:
      nc_sizes.append(nc.size)

  y_ax = np.linspace(1, 0, len(nc_sizes))
  plt.scatter(nc_sizes, y_ax)
  plt.title(title)
  plt.ylabel('Fraction Beaten')
  plt.xlabel('Cluster Size')

def compute_RPP(nc1, nc2, payoff):
    p_vect1 = np.zeros(payoff.shape[0]); p_vect2 = np.zeros(payoff.shape[0])
    
    p_vect1[nc1.strat_idx] = nc1.probability; p_vect2[nc2.strat_idx] = nc2.probability
    return (p_vect1.reshape(1, -1) @ payoff @ p_vect2.reshape(-1, 1)).item()
    
def generate_RPP_data(nash_clusters, payoff):
    data_tuples_rpp = []; n_nc = len(nash_clusters); data_tuples_rpp_sign = []; rpp_mat = np.zeros((n_nc, n_nc))
    for i, nc_i in enumerate(nash_clusters):
        rpp_sum = 0; rpp_sign_sum = 0
        for j, nc_j in enumerate(nash_clusters):
            if i != j:
                rpp = compute_RPP(nc_i, nc_j, payoff)
                rpp_mat[i,j] = rpp
                rpp_sum += rpp
                rpp_sign_sum += 1 * (rpp >= 0)

        rpp_sum = rpp_sum / n_nc; rpp_sign_sum = rpp_sign_sum / (n_nc - 1)

        data_tuples_rpp.append([nc_i.size, rpp_sum])
        data_tuples_rpp_sign.append([nc_i.size, rpp_sign_sum])

    return np.array(data_tuples_rpp), np.array(data_tuples_rpp_sign), rpp_mat

def generate_RPS_data(payoff):
    signed_payoff = 1 * (payoff > 0)
    strat_winrate = np.mean(payoff > 0, axis = 1)
    adj = signed_payoff @ signed_payoff @ signed_payoff
    
    return np.diag(adj), strat_winrate

def plot_RPS(adj, strat_winrate, title):
    plt.title(title)
    plt.xlabel('RPS Cycles')
    plt.ylabel('Mean Win-Rate')
    plt.scatter(adj, strat_winrate)
    
def plot_nash_clusters_2(sign_rpp, title):
    plt.scatter(sign_rpp[:, 0], sign_rpp[:, 1])
    plt.title(title)
    plt.ylabel('Fraction Beaten (RPP)')
    plt.xlabel('Cluster Size')
    
def plot_nash_clusters_3(sign_rpp, title, seed = 88):
    plt.scatter(sign_rpp[:, 0], sign_rpp[:, 1])
    plt.title(title)
    plt.ylabel('Fraction Beaten (RPP)')
    plt.xlabel('Cluster Size')
    
    # Fit skewed normal
    np.random.seed(seed)
    y_data = sign_rpp[:, 0]; x_data = sign_rpp[:, 1]
    init = np.random.uniform(1, 3, size = (5))
    params = fit_skewed_normal(init, x_data, y_data)
    
    inputs = np.linspace(0, 1, 1000)
    outputs = affine_skewed_normal_pdf(params, inputs)
    plt.plot(outputs, inputs)
    
    return params
    
# Test using scipy.optimize.minimize. Need a function to minimize with signature function(x, *args), where x is a list
# of the parameters to optimize. Syntax: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize
def affine_skewed_normal_loss(parameters, xdata, ydata):
    """
    parameters shape is [\mu, \sigma, \alpha, \a, \b]
    """
    mu, sigma, alpha, a, b = parameters
    
    # Compute the loss
    out = a * (sigma ** 2) * skewnorm.pdf(xdata, alpha, mu, sigma**2) + b
#     out = a * skewnorm.pdf(xdata, alpha, mu, sigma) + b
    loss = np.sum((out - ydata) ** 2)
    
    return loss

def affine_skewed_normal_pdf(parameters, xdata):
    mu, sigma, alpha, a, b = parameters
    out = a * (sigma ** 2) * skewnorm.pdf(xdata, alpha, mu, sigma**2) + b
#     out = a * skewnorm.pdf(xdata, alpha, mu, sigma) + b
    return out

def fit_skewed_normal(init, xdata, ydata):
    bnds = [(None, None), (1e-15, None), (None, None), (None, None), (None, None)]
    results = minimize(affine_skewed_normal_loss, init, args = (xdata, ydata), bounds = bnds, tol = 1e-8)
    return results.x

def compute_win_rate(curr_idx, payoff):
    return np.mean(payoff[curr_idx, :])

def savePickle(var, name):
    with open(name+'.pickle', 'wb') as handle:
        pickle.dump(var, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
def openPickle(name):
    filename = name+'.pickle'
    with open(filename,'rb') as f:
        var = pickle.load(f)
    return var

def generate_elo_nc_data(nash_clusters, lower_bound, upper_bound, n):
    bins = create_bins(lower_bound, upper_bound, n)
    mid_bins = np.mean(np.array(bins), axis = 1)
    data = []
    
    for nc in nash_clusters:
        ori_idx = nc.strat_idx
        av_elo = np.mean(mid_bins[ori_idx])
        data.append([nc.size, av_elo])
    
    return np.array(data)

def plot_elo_nc(data, title):
    plt.title(title)
    plt.xlabel('Nash Cluster Size')
    plt.ylabel('Average Elo')
    plt.scatter(data[:,0], data[:, 1])

# %%
print(cp.installed_solvers())
# Out:
# ['CVXOPT', 'ECOS', 'ECOS_BB', 'GLPK', 'GLPK_MI', 'MOSEK', 'OSQP', 'SCS']

# %% [markdown]
# ### Chess 1000 x 1000

# %%
# Note: 1st saved matrix is from 800 - 2500
# 2nd saved is 800 - 2800
# 3rd saved is 800 - 2650
# 5 saved is 950 - 2700
# 6 saved is 900 - 2750
# 7 saved is 850 - 2750
# 8 saved is 800 - 2750
# 9: 750 - 2800
# 10: 750 - 2850
# 11: 750 - 2900
# 12: 750 - 2950

# %%
title = 'Chess 1500 (2013)'

# %%
nash_clusters = openPickle('Data/2013/2013 nash_clusters_1500_12')
rpp_mat = openPickle('Data/2013/2013 rpp_mat_1500_12')
rpp_sign_tuples = openPickle("Data/2013/2013 rpp_sign_tuples_1500_12")
rpp_tuples = openPickle("Data/2013/2013 rpp_tuples_1500_12")

# %%
payoff = openPickle('Data/2013/ChessPayoff12 1500')
markers = openPickle('Data/2013/ChessMarkers12 1500')

# %%
payoff, markers = create_payoff(1500, 750, 2950)
where_zeros = np.where(np.abs(payoff) <= 1e-7)
payoff[where_zeros[0], where_zeros[1]] = 0
# Out:
# 100%|██████████| 1500/1500 [6:58:43<00:00, 16.75s/it]

# %%
nash_clusters, markers_instances, unsolved_cases = Nash_Clustering(payoff, markers)
# Out:
# Iteration 0
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1499
# Payoff remaining size 1499
# Iteration 1
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1498
# Payoff remaining size 1498
# Iteration 2
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1497
# Payoff remaining size 1497
# Iteration 3
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1496
# Payoff remaining size 1496
# Iteration 4
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1495
# Payoff remaining size 1495
# Iteration 5
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1494
# Payoff remaining size 1494
# Iteration 6
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1493
# Payoff remaining size 1493
# Iteration 7
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1492
# Payoff remaining size 1492
# Iteration 8
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1491
# Payoff remaining size 1491
# Iteration 9
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1490
# Payoff remaining size 1490
# Iteration 10
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1489
# Payoff remaining size 1489
# Iteration 11
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1488
# Payoff remaining size 1488
# Iteration 12
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1487
# Payoff remaining size 1487
# Iteration 13
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1486
# Payoff remaining size 1486
# Iteration 14
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1485
# Payoff remaining size 1485
# Iteration 15
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1484
# Payoff remaining size 1484
# Iteration 16
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1483
# Payoff remaining size 1483
# Iteration 17
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1482
# Payoff remaining size 1482
# Iteration 18
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1481
# Payoff remaining size 1481
# Iteration 19
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1480
# Payoff remaining size 1480
# Iteration 20
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1479
# Payoff remaining size 1479
# Iteration 21
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1478
# Payoff remaining size 1478
# Iteration 22
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1477
# Payoff remaining size 1477
# Iteration 23
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1476
# Payoff remaining size 1476
# Iteration 24
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1475
# Payoff remaining size 1475
# Iteration 25
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1474
# Payoff remaining size 1474
# Iteration 26
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1473
# Payoff remaining size 1473
# Iteration 27
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1472
# Payoff remaining size 1472
# Iteration 28
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1471
# Payoff remaining size 1471
# Iteration 29
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1470
# Payoff remaining size 1470
# Iteration 30
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1469
# Payoff remaining size 1469
# Iteration 31
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1468
# Payoff remaining size 1468
# Iteration 32
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1467
# Payoff remaining size 1467
# Iteration 33
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1466
# Payoff remaining size 1466
# Iteration 34
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1465
# Payoff remaining size 1465
# Iteration 35
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1464
# Payoff remaining size 1464
# Iteration 36
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1463
# Payoff remaining size 1463
# Iteration 37
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1462
# Payoff remaining size 1462
# Iteration 38
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1461
# Payoff remaining size 1461
# Iteration 39
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1460
# Payoff remaining size 1460
# Iteration 40
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1459
# Payoff remaining size 1459
# Iteration 41
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1458
# Payoff remaining size 1458
# Iteration 42
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1457
# Payoff remaining size 1457
# Iteration 43
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1456
# Payoff remaining size 1456
# Iteration 44
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1455
# Payoff remaining size 1455
# Iteration 45
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1454
# Payoff remaining size 1454
# Iteration 46
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1453
# Payoff remaining size 1453
# Iteration 47
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1452
# Payoff remaining size 1452
# Iteration 48
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1451
# Payoff remaining size 1451
# Iteration 49
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1450
# Payoff remaining size 1450
# Iteration 50
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1449
# Payoff remaining size 1449
# Iteration 51
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1448
# Payoff remaining size 1448
# Iteration 52
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1447
# Payoff remaining size 1447
# Iteration 53
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1446
# Payoff remaining size 1446
# Iteration 54
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1445
# Payoff remaining size 1445
# Iteration 55
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1444
# Payoff remaining size 1444
# Iteration 56
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1443
# Payoff remaining size 1443
# Iteration 57
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1442
# Payoff remaining size 1442
# Iteration 58
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1441
# Payoff remaining size 1441
# Iteration 59
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1440
# Payoff remaining size 1440
# Iteration 60
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1439
# Payoff remaining size 1439
# Iteration 61
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1438
# Payoff remaining size 1438
# Iteration 62
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1437
# Payoff remaining size 1437
# Iteration 63
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1436
# Payoff remaining size 1436
# Iteration 64
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1435
# Payoff remaining size 1435
# Iteration 65
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1434
# Payoff remaining size 1434
# Iteration 66
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1433
# Payoff remaining size 1433
# Iteration 67
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1432
# Payoff remaining size 1432
# Iteration 68
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1431
# Payoff remaining size 1431
# Iteration 69
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1430
# Payoff remaining size 1430
# Iteration 70
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1429
# Payoff remaining size 1429
# Iteration 71
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1428
# Payoff remaining size 1428
# Iteration 72
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1427
# Payoff remaining size 1427
# Iteration 73
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1426
# Payoff remaining size 1426
# Iteration 74
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1425
# Payoff remaining size 1425
# Iteration 75
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1424
# Payoff remaining size 1424
# Iteration 76
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1423
# Payoff remaining size 1423
# Iteration 77
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1422
# Payoff remaining size 1422
# Iteration 78
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1421
# Payoff remaining size 1421
# Iteration 79
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1420
# Payoff remaining size 1420
# Iteration 80
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1419
# Payoff remaining size 1419
# Iteration 81
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1418
# Payoff remaining size 1418
# Iteration 82
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1417
# Payoff remaining size 1417
# Iteration 83
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1416
# Payoff remaining size 1416
# Iteration 84
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1415
# Payoff remaining size 1415
# Iteration 85
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1414
# Payoff remaining size 1414
# Iteration 86
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1413
# Payoff remaining size 1413
# Iteration 87
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1412
# Payoff remaining size 1412
# Iteration 88
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1411
# Payoff remaining size 1411
# Iteration 89
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1410
# Payoff remaining size 1410
# Iteration 90
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1409
# Payoff remaining size 1409
# Iteration 91
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1408
# Payoff remaining size 1408
# Iteration 92
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1407
# Payoff remaining size 1407
# Iteration 93
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1406
# Payoff remaining size 1406
# Iteration 94
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1405
# Payoff remaining size 1405
# Iteration 95
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1404
# Payoff remaining size 1404
# Iteration 96
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1403
# Payoff remaining size 1403
# Iteration 97
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1402
# Payoff remaining size 1402
# Iteration 98
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1401
# Payoff remaining size 1401
# Iteration 99
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1400
# Payoff remaining size 1400
# Iteration 100
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1399
# Payoff remaining size 1399
# Iteration 101
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1398
# Payoff remaining size 1398
# Iteration 102
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1397
# Payoff remaining size 1397
# Iteration 103
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1396
# Payoff remaining size 1396
# Iteration 104
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1395
# Payoff remaining size 1395
# Iteration 105
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1394
# Payoff remaining size 1394
# Iteration 106
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1393
# Payoff remaining size 1393
# Iteration 107
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1392
# Payoff remaining size 1392
# Iteration 108
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1391
# Payoff remaining size 1391
# Iteration 109
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1390
# Payoff remaining size 1390
# Iteration 110
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1389
# Payoff remaining size 1389
# Iteration 111
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1388
# Payoff remaining size 1388
# Iteration 112
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1387
# Payoff remaining size 1387
# Iteration 113
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1386
# Payoff remaining size 1386
# Iteration 114
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1385
# Payoff remaining size 1385
# Iteration 115
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1384
# Payoff remaining size 1384
# Iteration 116
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1383
# Payoff remaining size 1383
# Iteration 117
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1382
# Payoff remaining size 1382
# Iteration 118
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1381
# Payoff remaining size 1381
# Iteration 119
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1380
# Payoff remaining size 1380
# Iteration 120
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1379
# Payoff remaining size 1379
# Iteration 121
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1378
# Payoff remaining size 1378
# Iteration 122
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1377
# Payoff remaining size 1377
# Iteration 123
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1376
# Payoff remaining size 1376
# Iteration 124
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1375
# Payoff remaining size 1375
# Iteration 125
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1374
# Payoff remaining size 1374
# Iteration 126
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1373
# Payoff remaining size 1373
# Iteration 127
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1372
# Payoff remaining size 1372
# Iteration 128
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1371
# Payoff remaining size 1371
# Iteration 129
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1370
# Payoff remaining size 1370
# Iteration 130
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1369
# Payoff remaining size 1369
# Iteration 131
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1368
# Payoff remaining size 1368
# Iteration 132
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1367
# Payoff remaining size 1367
# Iteration 133
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1366
# Payoff remaining size 1366
# Iteration 134
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1365
# Payoff remaining size 1365
# Iteration 135
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1364
# Payoff remaining size 1364
# Iteration 136
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1363
# Payoff remaining size 1363
# Iteration 137
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1362
# Payoff remaining size 1362
# Iteration 138
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1361
# Payoff remaining size 1361
# Iteration 139
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1360
# Payoff remaining size 1360
# Iteration 140
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1359
# Payoff remaining size 1359
# Iteration 141
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1358
# Payoff remaining size 1358
# Iteration 142
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1357
# Payoff remaining size 1357
# Iteration 143
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1356
# Payoff remaining size 1356
# Iteration 144
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1355
# Payoff remaining size 1355
# Iteration 145
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1354
# Payoff remaining size 1354
# Iteration 146
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1353
# Payoff remaining size 1353
# Iteration 147
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1352
# Payoff remaining size 1352
# Iteration 148
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1351
# Payoff remaining size 1351
# Iteration 149
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1350
# Payoff remaining size 1350
# Iteration 150
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1349
# Payoff remaining size 1349
# Iteration 151
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1348
# Payoff remaining size 1348
# Iteration 152
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1347
# Payoff remaining size 1347
# Iteration 153
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1346
# Payoff remaining size 1346
# Iteration 154
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1345
# Payoff remaining size 1345
# Iteration 155
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1344
# Payoff remaining size 1344
# Iteration 156
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1343
# Payoff remaining size 1343
# Iteration 157
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1342
# Payoff remaining size 1342
# Iteration 158
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1341
# Payoff remaining size 1341
# Iteration 159
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1340
# Payoff remaining size 1340
# Iteration 160
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1339
# Payoff remaining size 1339
# Iteration 161
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1338
# Payoff remaining size 1338
# Iteration 162
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1337
# Payoff remaining size 1337
# Iteration 163
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1336
# Payoff remaining size 1336
# Iteration 164
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1335
# Payoff remaining size 1335
# Iteration 165
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1334
# Payoff remaining size 1334
# Iteration 166
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1333
# Payoff remaining size 1333
# Iteration 167
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1332
# Payoff remaining size 1332
# Iteration 168
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1331
# Payoff remaining size 1331
# Iteration 169
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1330
# Payoff remaining size 1330
# Iteration 170
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1329
# Payoff remaining size 1329
# Iteration 171
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1328
# Payoff remaining size 1328
# Iteration 172
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1327
# Payoff remaining size 1327
# Iteration 173
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1326
# Payoff remaining size 1326
# Iteration 174
# Cycle count 0, diff = 0
# Outside, diff = 0
# APPENDING UNSOLVED CASE
# Strategies left 1325
# Payoff remaining size 1325
# Iteration 175
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-23-356b46c5fb04> in <module>
# ----> 1 nash_clusters, markers_instances, unsolved_cases = Nash_Clustering(payoff, markers)
#
# <ipython-input-18-76c2e142d45a> in Nash_Clustering(payoff, marker, algo, eps, zero_tol)
#     255
#     256         if algo == 'cvx': # solve using cvxpy, seems to be the only one working for now
# --> 257             nash_eq, diff = solve_MaxEnt_NE(curr_payoff, eps =1e-4, zero_tol = zero_tol, iters = int(2e4), cycle = 5)
#     258             print(f"Outside, diff = {diff}")
#     259             p_vect = nash_eq[nash_eq >= zero_tol]
#
# <ipython-input-18-76c2e142d45a> in solve_MaxEnt_NE(payoff, verbose, eps, zero_tol, iters, cycle)
#     197       cycle_count = 0; done = False
#     198       while cycle_count < cycle and done is False:
# --> 199         prob.solve(verbose = verbose, solver = cp.MOSEK, warm_start = True)
#     200         p_vect = p.value * (p.value > zero_tol)
#     201         diff = payoff @ p_vect.reshape(-1, 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvxpy\problems\problem.py in solve(self, *args, **kwargs)
#     460         else:
#     461             solve_func = Problem._solve
# --> 462         return solve_func(self, *args, **kwargs)
#     463
#     464     @classmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvxpy\problems\problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     956                     solving_chain.reductions[-1].name())
#     957         start = time.time()
# --> 958         solution = solving_chain.solve_via_data(
#     959             self, data, warm_start, verbose, kwargs)
#     960         end = time.time()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py in solve_via_data(self, problem, data, warm_start, verbose, solver_opts)
#     341             a Solution object.
#     342         """
# --> 343         return self.solver.solve_via_data(data, warm_start, verbose,
#     344                                           solver_opts, problem._solver_cache)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvxpy\reductions\solvers\conic_solvers\mosek_conif.py in solve_via_data(self, data, warm_start, verbose, solver_opts, solver_cache)
#     219                 env = mosek.Env()
#     220                 task = env.Task(0, 0)
# --> 221                 task = MOSEK._build_dualized_task(task, data)
#     222         else:
#     223             if len(data[s.C]) == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvxpy\reductions\solvers\conic_solvers\mosek_conif.py in _build_dualized_task(task, data)
#     274         # equality constraints
#     275         rows, cols, vals = sp.sparse.find(A)
# --> 276         task.putaijlist(rows.tolist(), cols.tolist(), vals.tolist())
#     277         task.putconboundlist(np.arange(n, dtype=int), [mosek.boundkey.fx] * n, b, b)
#     278         # conic constraints
#
# C:\ProgramData\Anaconda3\lib\site-packages\mosek\__init__.py in putaijlist(self, _arg2_subi, _arg3_subj, _arg4_valij)
#    7793       if res != 0:
#    7794         result,msg = self.__getlasterror(res)
# -> 7795         raise Error(rescode(res),msg)
#    7796
#    7797     def putacol(self,_arg1_j,_arg3_subj,_arg4_valj): # 3
#
# Error: rescode.err_space(1051): Out of space.

# %%
rpp_tuples, rpp_sign_tuples, rpp_mat = generate_RPP_data(nash_clusters, payoff)
adj, strat_winrate = generate_RPS_data(payoff)
plot_RPS(adj, strat_winrate, title)

# %%
y_data = rpp_sign_tuples[:, 0]; x_data = rpp_sign_tuples[:, 1]
np.random.seed(8)
init = np.random.uniform(1, 3, size = (5))
print(init)
params = fit_skewed_normal(init, x_data, y_data)
print(params)

# %%
seed = 88888888
params = plot_nash_clusters_3(rpp_sign_tuples, title, seed)

# %%
savePickle(params, '2013 NC Plot params')

# %%
plt.figure(figsize = (15,8))
plt.title(title)
sb.heatmap(rpp_mat, cmap = 'RdBu', xticklabels = False, yticklabels = False, annot = False)
# Out:
# <AxesSubplot:title={'center':'Chess 1000 (2013)'}>

# %%
savePickle(payoff, 'Data/2013/ChessPayoff12 1500')
savePickle(markers, 'Data/2013/ChessMarkers12 1500')

# %% [markdown]
# ### Histogram Data Extraction

# %%
year = 2013
elos = np.concatenate([white_elos, black_elos])
bins = create_bins(750, 2950, 100)
bins = np.array(bins)
hist_bins = np.concatenate([bins[:, 0], [2950]])
plt.title(title + ' Elo Histogram')
out = plt.hist(elos, bins = hist_bins)

# %%
# Data to reproduce plots
counts = out[0]; act_counts = counts
mid_bins = np.mean(bins, axis = 1)
counts = counts / np.sum(counts)
plt.scatter(mid_bins, counts)
set_data = [mid_bins, counts]
count_data = [mid_bins, act_counts]
# savePickle(set_data, 'Data/'+ str(year)+ '/Histogram Data')

# %%
# Fit skewed normal
plt.scatter(counts, mid_bins)
seed = 888
np.random.seed(seed)
y_data = counts; x_data = mid_bins
init = np.random.uniform(0, 0.5, size = (5))
init[0] = 1500; init[1] = 10 * np.sqrt(2)
params = fit_skewed_normal(init, x_data, y_data)

inputs = np.linspace(750, 2950, 1500)
outputs = affine_skewed_normal_pdf(params, inputs)
plt.plot(outputs, inputs)

# %%
# Save fitted params so no need to repeat
savePickle(params, 'Data/'+str(year)+'/Histogram Param')
savePickle(set_data, 'Data/'+ str(year)+ '/Histogram Data')
savePickle(elos, 'Data/'+str(year)+'/Histogram Elos')
savePickle(count_data, 'Data/'+str(year)+'/Histogram Count Data')

# %% [markdown]
# ### Training Data Extraction

# %%
# With Uniform

def compute_win_rate(curr_idx, payoff):
    return np.mean(payoff[curr_idx, :])

def generate_training_data(payoff, pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300, 350]):
    win_rates_results = dict()

    for pop_size in pop_sizes:
        print(f"Population Size {pop_size}")
        win_rates = []
        strat_strengths = np.mean(payoff > 0, axis = 1)
        ordering_idx = np.argsort(strat_strengths)

        curr_strat_idx = list(ordering_idx[:pop_size])
        win_rates.append(compute_win_rate(curr_strat_idx, payoff))
        n_iters = 2000; it = 0
        converge = False
        while it < n_iters:
            taken_payoff = np.sum(payoff[:, curr_strat_idx], axis = 1)
            viable_strats = np.where(taken_payoff > 0)[0]
            not_in = ~np.isin(viable_strats, curr_strat_idx)
            viable_strats = viable_strats[not_in]
            if len(viable_strats) > 0:
                viable_strengths = strat_strengths[viable_strats]
                sorted_idx = np.argsort(viable_strengths)
                new_strat = viable_strats[sorted_idx[0]]
                curr_strat_idx.append(new_strat)
                curr_strat_idx = curr_strat_idx[1:]
            else:
                if converge == False:
                    converge = True
                    it_conv = it
                    print(f"First Reached Peak at {it_conv}")


            win_rates.append(compute_win_rate(curr_strat_idx, payoff))
            it += 1

        if converge == False:
            print(f"Population size {pop_size} doesn't converge")
            
        win_rates_results[pop_size] = win_rates
    
    return win_rates_results

def plot_training(win_rates_results, title, save = False):
    plt.figure(figsize = (10,8))
    plt.title(title)
    for pop_size in win_rates_results.keys():
        win_rates = win_rates_results[pop_size]
        plt.plot(np.arange(len(win_rates)), win_rates, label = str(pop_size))
        
    plt.xlabel('Iterations')
    plt.ylabel('Mean Win Rate')
    plt.legend(title = 'Population Size')
    
    if save:
        plt.savefig('Training Plots.pdf')

# %%
payoff = openPickle('Data/2013/ChessPayoff12 1500')

# %%
pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300]
training_performances = generate_training_data(payoff, pop_sizes)
# Out:
# Population Size 1
# Population size 1 doesn't converge
# Population Size 25
# Population size 25 doesn't converge
# Population Size 50
# First Reached Peak at 1527
# Population Size 75
# First Reached Peak at 1431
# Population Size 100
# First Reached Peak at 1400
# Population Size 150
# First Reached Peak at 1350
# Population Size 200
# First Reached Peak at 1300
# Population Size 250
# First Reached Peak at 1250
# Population Size 300
# First Reached Peak at 1200

# %%
plot_training(training_performances, 'Lichess 2013')

# %%
savePickle(training_performances, 'Lichess 2013 Training Uniform')

# %%
# With Nash
def compute_win_rate(curr_idx, payoff):
    return np.mean(payoff[curr_idx, :])

def compute_win_rate3(curr_strat_idx, payoff):
    # With Nash
    pop_size = len(curr_strat_idx)
    taken_idx = np.array(list(itertools.product(curr_strat_idx, repeat = 2)))
    taken_payoff = payoff[taken_idx[:, 0], taken_idx[:, 1]].reshape(pop_size, pop_size)
    p_vect, _ = solve_MaxEnt_NE(taken_payoff)
    prob_vect = np.zeros((payoff.shape[0]))
    prob_vect[curr_strat_idx] = p_vect
    return np.mean(prob_vect.reshape(1, -1) @ payoff)

def generate_training_data3(payoff, pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300, 350]):
    win_rates_results = dict()

    for pop_size in pop_sizes:
        print(f"Population Size {pop_size}")
        win_rates = []
        strat_strengths = np.mean(payoff > 0, axis = 1)
        ordering_idx = np.argsort(strat_strengths)

        curr_strat_idx = list(ordering_idx[:pop_size])
        if pop_size == 1:
            win_rates.append(compute_win_rate(curr_strat_idx, payoff))
        else:
            win_rates.append(compute_win_rate3(curr_strat_idx, payoff))
        n_iters = 2000; it = 0
        converge = False; prev_win_rate = 0
        while it < n_iters:
            taken_payoff = np.sum(payoff[:, curr_strat_idx], axis = 1)
            viable_strats = np.where(taken_payoff > 0)[0]
            not_in = ~np.isin(viable_strats, curr_strat_idx)
            viable_strats = viable_strats[not_in]
            if len(viable_strats) > 0:
                viable_strengths = strat_strengths[viable_strats]
                sorted_idx = np.argsort(viable_strengths)
                new_strat = viable_strats[sorted_idx[0]]
                curr_strat_idx.append(new_strat)
                curr_strat_idx = curr_strat_idx[1:]
            else:
                if converge == False:
                    converge = True
                    it_conv = it
                    print(f"First Reached Peak at {it_conv}")

            if pop_size == 1:
                win_rates.append(compute_win_rate(curr_strat_idx, payoff))
            else:
                if converge:
                    win_rates.append(prev_win_rate)
                else:
                    prev_win_rate = compute_win_rate3(curr_strat_idx, payoff)
                    win_rates.append(prev_win_rate)
                    
            it += 1

        if converge == False:
            print(f"Population size {pop_size} doesn't converge")
            
        win_rates_results[pop_size] = win_rates
    
    return win_rates_results

def solve_MaxEnt_NE(payoff, verbose = False, eps = 1e-5, zero_tol = 1e-6, iters = 500, cycle = 5):
    
    init_val = np.random.uniform(size = payoff.shape[0])
    init_val = init_val / np.sum(init_val)
    
    p = cp.Variable(payoff.shape[0], value = init_val)
    constraints = [payoff @ p <= 0, cp.sum(p) == 1, p >= 0]
    objective = cp.sum(cp.entr(p))
    prob = cp.Problem(cp.Maximize(objective), constraints)
    
    try:
      cycle_count = 0; done = False
      while cycle_count < cycle and done is False:
        prob.solve(verbose = verbose, solver = cp.MOSEK, warm_start = True)
        p_vect = p.value * (p.value > zero_tol)
        diff = payoff @ p_vect.reshape(-1, 1)
#         print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
        done = True if np.sum(diff >= eps) == 0 else False
        cycle_count += 1
    except cp.SolverError:
      print("MOSEK FAILED?")
      try:
        # Try ECOS_BB first
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = 1000, solver = cp.ECOS_BB, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
#           print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
      except cp.SolverError:
        print("ECOS_BB FAILED")
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = iters, solver = cp.SCS, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
#           print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
  
    # Clean - small values
    p_vect = p_vect * (p_vect > zero_tol)
    return p_vect, np.sum(diff>=eps)

# %%
pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300]
training_performances_nash = generate_training_data3(payoff, pop_sizes)
# Out:
# Population Size 1
# Population size 1 doesn't converge
# Population Size 25
# MOSEK FAILED?
# Population size 25 doesn't converge
# Population Size 50
# First Reached Peak at 1527
# Population Size 75
# First Reached Peak at 1431
# Population Size 100
# First Reached Peak at 1400
# Population Size 150
# First Reached Peak at 1350
# Population Size 200
# First Reached Peak at 1300
# Population Size 250
# First Reached Peak at 1250
# Population Size 300
# First Reached Peak at 1200

# %%
plot_training(training_performances_nash, 'Lichess 2013')

# %%
savePickle(training_performances_nash, 'Lichess 2013 Training Nash')
