# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nashpy as nash
import itertools
import cvxpy as cp
import cvxopt
from tqdm import tqdm
import seaborn as sb
from scipy.stats import skewnorm
from scipy.optimize import minimize
import pickle

# %%
# Fill in missing based on elo ratings
def win_rate_elo(elo1, elo2, alpha = np.log(10)/400):
    """
    Computes win rate of player 1 to player 2 given their elo ratings
    """
    return 1 / (1 + np.exp(-alpha * (elo1 - elo2)))

# %%
df = pd.read_csv('Data/2020/2020_All.csv')

# %%
df = df.iloc[:, 1:]
df
# Out:
#                        White           Black Result  WhiteElo  BlackElo
# 0                      odalv      pepeniloya    1-0      1492      1119
# 1                nathanleiby         neerajr    0-1      1449      1323
# 2                  PrillawTR           OUT1S    1-0      1186      1185
# 3                gekkognecco         JBF1965    1-0      2013      2063
# 4        Dr_Polanov-Wryeskij        negaksob    1-0      1998      1971
# ...                      ...             ...    ...       ...       ...
# 1439995             shahin56  crooklyn_jones    1-0      1595      1588
# 1439996             alemon25          mixo23    1-0      2329      2407
# 1439997      Impactoprofundo       Korabikab    1-0      2247      2029
# 1439998      batikentyagmuru    AgentJake006    0-1      1221      1159
# 1439999              Zoran86   Joseanobile19    0-1      1816      1798
#
# [1440000 rows x 5 columns]

# %%
df.head()
# Out:
#                  White       Black Result  WhiteElo  BlackElo
# 0                odalv  pepeniloya    1-0      1492      1119
# 1          nathanleiby     neerajr    0-1      1449      1323
# 2            PrillawTR       OUT1S    1-0      1186      1185
# 3          gekkognecco     JBF1965    1-0      2013      2063
# 4  Dr_Polanov-Wryeskij    negaksob    1-0      1998      1971

# %%
df = df.rename(columns = {'White': 'white_player', 'Black': 'black_player', 'Result':'result',
                         'WhiteElo': 'white_elo', 'BlackElo':'black_elo'})

df.head()
# Out:
#           white_player black_player result  white_elo  black_elo
# 0                odalv   pepeniloya    1-0       1492       1119
# 1          nathanleiby      neerajr    0-1       1449       1323
# 2            PrillawTR        OUT1S    1-0       1186       1185
# 3          gekkognecco      JBF1965    1-0       2013       2063
# 4  Dr_Polanov-Wryeskij     negaksob    1-0       1998       1971

# %%
df[df['result'] == '*']
# Out:
#          white_player        black_player result  white_elo  black_elo
# 418          SucioDan          ElyMiranda      *       1441       1276
# 2863          leame13            Neptalio      *       1464       1457
# 2949        Francis10  antoniofatone-1995      *       1575       1741
# 3446             ern7           divine3k8      *       1512       1552
# 4346          epicurr           HyperRuin      *       1146       1149
# ...               ...                 ...    ...        ...        ...
# 1439917  thusomosutha  leondeparque881517      *       2247       2275
# 1439951     Dralsaadi            bomilkar      *       1678       1589
# 1439975         NEO24             gibas58      *       1949       2021
# 1439991     Muslim095             trxctyr      *       1371       1330
# 1439992     kolosovas             Ivanhof      *       2189       2065
#
# [1180 rows x 5 columns]

# %%
possible_results = ['0-1', '1-0', '1/2-1/2']
drop_idx = df[~df['result'].isin(possible_results)].index
df = df.drop(drop_idx)

df[df['result'] == '*']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %% [markdown]
# Drop unknown elo ratings

# %%
drop_idx = df[df['white_elo'] == '?'].index
df = df.drop(drop_idx)

df[df['white_elo'] == '?']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %%
drop_idx = df[df['black_elo'] == '?'].index
df = df.drop(drop_idx)

df[df['black_elo'] == '?']
# Out:
# Empty DataFrame
# Columns: [white_player, black_player, result, white_elo, black_elo]
# Index: []

# %%
# Convert to win-draw-lose
df.loc[df['result'] == '0-1', 'result'] = -1
df.loc[df['result'] == '1-0', 'result'] = 1
df.loc[df['result'] == '1/2-1/2', 'result'] = 0

# %%
# Convert ratings to integers
df['white_elo'] = np.array(df['white_elo']).astype('int64')
df['black_elo'] = np.array(df['black_elo']).astype('int64')

# %%
white_elos = np.array(df['white_elo'])
black_elos = np.array(df['black_elo'])

# %%
plt.title('White Elo Histogram')
plt.hist(white_elos)
# Out:
# (array([6.13600e+03, 7.75800e+04, 2.29971e+05, 3.66118e+05, 3.93085e+05,
#         2.61749e+05, 8.80090e+04, 1.44200e+04, 1.65700e+03, 9.50000e+01]),
#  array([ 600. ,  864.3, 1128.6, 1392.9, 1657.2, 1921.5, 2185.8, 2450.1,
#         2714.4, 2978.7, 3243. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.title('Black Elo Histogram')
plt.hist(black_elos)
# Out:
# (array([6.83100e+03, 8.69290e+04, 2.50819e+05, 3.87814e+05, 3.95999e+05,
#         2.34064e+05, 6.62900e+04, 9.19100e+03, 8.52000e+02, 3.10000e+01]),
#  array([ 600. ,  872.8, 1145.6, 1418.4, 1691.2, 1964. , 2236.8, 2509.6,
#         2782.4, 3055.2, 3328. ]),
#  <BarContainer object of 10 artists>)

# %%
white_ratings, counts = np.unique(white_elos, return_counts = True)
black_ratings, counts = np.unique(black_elos, return_counts = True)

# %%
white_min = np.min(white_elos); white_max = np.max(white_elos)
black_min = np.min(black_elos); black_max = np.max(black_elos)

print(f"For white, min = {white_min}, max = {white_max}")
print(f"For black, min = {black_min}, max = {black_max}")

# Bounds should be the 'loose' one. Might want to cut down in case there's no matchups
lb = min(white_min, black_min); ub = max(white_max, black_max)
print(f"Bins range {lb} - {ub}")
# Out:
# For white, min = 600, max = 3243
# For black, min = 600, max = 3328
# Bins range 600 - 3328

# %% [markdown]
# ## Creating the payoffs
#
# ### Method 1: Sample uniformly n-bins from the range above, and average the win rate. Win counts for +1, loss -1, draw 0

# %%
def create_bins(lower_bound, upper_bound, n):
    width = (upper_bound - lower_bound) / n
    
    ub = lower_bound + width; lb = lower_bound; bins = [(lb, ub)]
    for _ in range(n-1):
        lb += width; ub += width; bins.append((lb, ub))
    
    return bins

def within(bin_range, num):
    return num >= bin_range[0] and num < bin_range[1]

# %%
# Check if data contains lower ratings beating greater ratings
sieve_greater = (df['white_elo'] <= df['black_elo']) & (df['result'] >= 0)
df[sieve_greater]
# Out:
#         game_id    type result   white_player  black_player  white_elo  \
# Index
# 1      WagNiFfQ   Blitz      0         batyko  ahli_blunder       1826
# 20     AAYKnWvt  Bullet      1   KingofKings7     alico1903       2046
# 25     7da3nkeh  Bullet      1        hshisug      Vperezgm       1887
# 26     M0Sl5CVI   Rapid      1           RRSR     jvmaximus       1903
# 38     EuGDHldp  Bullet      1  super-code_ru     Misilleme        800
# ...         ...     ...    ...            ...           ...        ...
# 15961  h8VdqGR9  Bullet      1  AUSTIN_PRINCE         kligs       1447
# 15962  doApPb6F   Blitz      1           zx14     KadrinEfe       1297
# 15965  PKRUE0x0   Rapid      1      panscrub5     vezir_mat       1672
# 15974  IWrb8b44   Blitz      1       flanky64         Bur54       1302
# 15977  Ery4GsZJ   Blitz      1      TemurAziz        KEDMNU       1389
#
#        black_elo
# Index
# 1           1826
# 20          2127
# 25          1924
# 26          1930
# 38           872
# ...          ...
# 15961       1461
# 15962       1308
# 15965       1672
# 15974       1304
# 15977       1500
#
# [45802 rows x 7 columns]

# %%
# Check if data contains lower ratings beating greater ratings
sieve_greater = (df['black_elo'] <= df['white_elo']) & (df['result'] <= 0)
df[sieve_greater]
# Out:
#         game_id    type result       white_player   black_player  white_elo  \
# Index
# 0      mAEz2AcC   Rapid     -1          AliKhaled        ifospor       1702
# 1      WagNiFfQ   Blitz      0             batyko   ahli_blunder       1826
# 8      Tr8HhqHt   Blitz     -1              BMWX5     nistvana83       1941
# 9      53OXpsTy  Bullet     -1           Vperezgm     Telesforus       1935
# 10     fHwNFnEm   Blitz     -1            ahhatip        inalcik       1133
# ...         ...     ...    ...                ...            ...        ...
# 15950  Bc0MxCBM  Bullet     -1  anton1dalnikovich      Pravin171       1409
# 15955  3dslmEH7   Blitz     -1          forrest92  Veter-Peremen       1863
# 15963  vuDze9mH   Blitz     -1          Stock2020   Pavlodar_pvl       2165
# 15976  CJGHaez8   Blitz     -1        gungorkeles        Nicozxc       1589
# 15978  ccZJzA45   Blitz     -1            Pvp9897    fatemeh1375       1239
#
#        black_elo
# Index
# 0           1628
# 1           1826
# 8           1894
# 9           1921
# 10           944
# ...          ...
# 15950       1396
# 15955       1837
# 15963       2165
# 15976       1562
# 15978       1182
#
# [42619 rows x 7 columns]

# %%
wlb, wub = (1829, 1832); blb, bub = (2001, 2003)

# %%
sieve_w = (df['white_elo'] < wub) & (df['white_elo'] > wlb)
df_sieve_w = df[sieve_w]
df_sieve_w['black_elo'].unique()
# Out:
# array([1792, 1841, 1983, 1805, 1925, 1763, 1751, 1778, 1872, 1721, 1756,
#        1881, 1620, 1724, 1842, 2104, 1704, 1829, 1830, 1803, 1781, 1686,
#        1557, 1573, 1546, 2013, 1959, 1860, 1806, 1956, 1862, 1657, 1764,
#        2078, 1838, 1749, 1865, 1766, 1699, 1583, 1691, 1807, 1825, 1740,
#        1797, 1750, 1722, 1934, 2012, 2034, 1891, 1843, 1637, 1826, 1905,
#        1820, 1676, 1856, 1895, 1747, 1606, 1898, 1782, 1965, 1730, 1821,
#        1818, 1684, 2056, 1801, 2004, 1789, 1998, 1920, 2207, 1811, 2015,
#        1668, 1828, 1526, 1773, 1834, 1744, 1732, 2049, 2062, 1835, 2046,
#        1688, 1927, 2020, 1815, 1709, 1824, 1919, 1693, 1772, 1816, 1975,
#        1878, 1879, 1485, 1893, 1753, 1864, 1804, 1532, 1587, 1836, 1802,
#        1888, 1664, 1913, 1831, 1736, 1882, 1832, 2080, 1787, 1798, 1729,
#        1850, 1977, 1746, 1989, 1840, 1450, 1775, 1774, 1972, 1997, 1706,
#        2433, 1790, 2018, 1745, 2447, 1930, 2146, 1839, 1886, 1757, 1851,
#        1896, 1921, 1786, 1917, 1863, 2245, 1735, 1855, 1915, 1785, 1914,
#        1903, 1780, 1955, 1796, 2112, 1813, 1769, 1810, 1852, 1812, 1932,
#        1887, 1845, 1822, 1349, 2124, 1793, 2061, 1854, 1848, 1714, 1936,
#        1897, 1765, 1833, 2009, 1727, 2308, 1784, 1791, 1900, 1795, 1817,
#        1847, 2135, 1937, 1758, 1869, 1868, 1809, 2002, 1468, 1397, 1644,
#        1837, 1814, 1904], dtype=int64)

# %%
# Functions
def create_payoff(n, bin_lb, bin_ub):
    # Construct payoff template and bins
    # Also returns marker array, to indicate whether one missing, both missing, or none missing
    bins = np.array(create_bins(bin_lb, bin_ub, n))
    payoff = np.ones((n, n)) * -8; np.fill_diagonal(payoff, 0)
    
    # Marker matrix to indicate missing data. 1 for both present, -1 for p1 white, -2 for p1 black, -3 for both series
    mat = np.zeros((n, n))
    
    for i in tqdm(range(len(bins))):
        for j in range(len(bins)):
           # These are actually p1 and p2 ratings. We want to find where this p1 rating is white vs p2 black and
            # then vice versa
            p1_bin_lb, p1_bin_ub = bins[i]
            p2_bin_lb, p2_bin_ub = bins[j] 
            
            # Mid-bin rating to predict if missing
            p1_rating = (p1_bin_ub + p1_bin_lb) / 2
            p2_rating = (p2_bin_ub + p2_bin_lb) / 2
            
            if p1_bin_lb >= p2_bin_lb:
                continue
            else:
                # Sieve off data
                p1_white = (df['white_elo'] < p1_bin_ub) & (df['white_elo'] >= p1_bin_lb)
                p2_white = (df['white_elo'] < p2_bin_ub) & (df['white_elo'] >= p2_bin_lb)

                p1_black = (df['black_elo'] < p1_bin_ub) & (df['black_elo'] >= p1_bin_lb)
                p2_black = (df['black_elo'] < p2_bin_ub) & (df['black_elo'] >= p2_bin_lb)

                # Count data available
                p1_white_counts = np.sum(p1_white); p1_black_counts = np.sum(p1_black)
                p2_white_counts = np.sum(p2_white); p2_black_counts = np.sum(p2_black)

                # bool_ser1 = p1 white and p2 black; bool_ser2 = p1 black and p2 white
                bool_ser1 = p1_white & p2_black; bool_ser2 = p1_black & p2_white
                ser1_count = np.sum(bool_ser1); ser2_count = np.sum(bool_ser2)

                if ser1_count != 0 and ser2_count != 0:
                    # Both matchups exist in data
                    # To get average, must put a - b, since if black wins, result is -1. Payoff matrix
                    # is wrt to player 1
                    value = (np.mean(df[bool_ser1]['result']) - np.mean(df[bool_ser2]['result'])) / 2
                    payoff[i,j] = value
                    payoff[j,i] = -value
                    mat[i,j] = 1; mat[j,i] = 1
                else:
                    if ser1_count !=0 and ser2_count == 0:
                        # i.e. series 2 matchup don't exist. Hence series 1 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 2 missing")
                        ser1_rate = np.mean(df[bool_ser1]['result'])

                        # Predict series 2 with elo. This don't care who is white/black
                        # NOTE: win probability is probability of player 1 winning, yielding a reward of +1
                        # To find expected score, must multiply probability with score
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser2_rate = win_prob * 1 + (1 - win_prob) * -1
                
                        value = (ser1_rate + ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -2
                        mat[j,i] = -2

                    if ser1_count == 0 and ser2_count != 0:
                        # i.e. series 1 matchup don't exist. Hence series 2 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 1 missing")
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser1_rate = win_prob * 1 + (1 - win_prob) * -1
                        ser2_rate = np.mean(df[bool_ser2]['result'])
                        value = (ser1_rate - ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -1; mat[j,i] = -1

                    if ser1_count == 0 and ser2_count == 0:
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, both missing")
                        # i.e. both are missing, predict using elo
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        value = win_prob * 1 + (1 - win_prob) * (-1)
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -3; mat[j,i] = -3
                        
    return payoff, mat


def create_payoff_2(white_bins, black_bins):
    # Construct payoff template and bins
    # Also returns marker array, to indicate whether one missing, both missing, or none missing
    n_row = len(white_bins); n_col = len(black_bins)
    payoff = np.ones((n_row, n_col)) * -8; np.fill_diagonal(payoff, 0)
    
    # Marker matrix to indicate missing data. 1 for both present, -1 for p1 white, -2 for p1 black, -3 for both series
    mat = np.zeros((n_row, n_col))
    
    for i in tqdm(range(n_row)):
        for j in range(range(n_col)):
           # These are actually p1 and p2 ratings. We want to find where this p1 rating is white vs p2 black and
            # then vice versa
            p1_bin_lb, p1_bin_ub = white_bins[i]
            p2_bin_lb, p2_bin_ub = black_bins[j]
            
            # Mid-bin rating to predict if missing
            p1_rating = (p1_bin_ub + p1_bin_lb) / 2
            p2_rating = (p2_bin_ub + p2_bin_lb) / 2
            
            if p1_bin_lb >= p2_bin_lb:
                continue
            else:
                # Sieve off data
                p1_white = (df['white_elo'] < p1_bin_ub) & (df['white_elo'] >= p1_bin_lb)
                p2_white = (df['white_elo'] < p2_bin_ub) & (df['white_elo'] >= p2_bin_lb)

                p1_black = (df['black_elo'] < p1_bin_ub) & (df['black_elo'] >= p1_bin_lb)
                p2_black = (df['black_elo'] < p2_bin_ub) & (df['black_elo'] >= p2_bin_lb)

                # Count data available
                p1_white_counts = np.sum(p1_white); p1_black_counts = np.sum(p1_black)
                p2_white_counts = np.sum(p2_white); p2_black_counts = np.sum(p2_black)

                # bool_ser1 = p1 white and p2 black; bool_ser2 = p1 black and p2 white
                bool_ser1 = p1_white & p2_black; bool_ser2 = p1_black & p2_white
                ser1_count = np.sum(bool_ser1); ser2_count = np.sum(bool_ser2)

                if ser1_count != 0 and ser2_count != 0:
                    # Both matchups exist in data
                    # To get average, must put a - b, since if black wins, result is -1. Payoff matrix
                    # is wrt to player 1
                    value = (np.mean(df[bool_ser1]['result']) - np.mean(df[bool_ser2]['result'])) / 2
                    payoff[i,j] = value
                    payoff[j,i] = -value
                    mat[i,j] = 1; mat[j,i] = 1
                else:
                    if ser1_count !=0 and ser2_count == 0:
                        # i.e. series 2 matchup don't exist. Hence series 1 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 2 missing")
                        ser1_rate = np.mean(df[bool_ser1]['result'])

                        # Predict series 2 with elo. This don't care who is white/black
                        # NOTE: win probability is probability of player 1 winning, yielding a reward of +1
                        # To find expected score, must multiply probability with score
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser2_rate = win_prob * 1 + (1 - win_prob) * -1
                
                        value = (ser1_rate + ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -2
                        mat[j,i] = -2

                    if ser1_count == 0 and ser2_count != 0:
                        # i.e. series 1 matchup don't exist. Hence series 2 use real data
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, series 1 missing")
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        ser1_rate = win_prob * 1 + (1 - win_prob) * -1
                        ser2_rate = np.mean(df[bool_ser2]['result'])
                        value = (ser1_rate - ser2_rate) / 2
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -1; mat[j,i] = -1

                    if ser1_count == 0 and ser2_count == 0:
#                         print(f"P1 rating {(p1_bin_lb, p1_bin_ub)}, P2 rating {(p2_bin_lb, p2_bin_ub)}, both missing")
                        # i.e. both are missing, predict using elo
                        win_prob = win_rate_elo(p1_rating, p2_rating)
                        value = win_prob * 1 + (1 - win_prob) * (-1)
                        payoff[i,j] = value
                        payoff[j,i] = -value
                        mat[i,j] = -3; mat[j,i] = -3
                        
    return payoff, mat
            
class NashCluster():
    
    def __init__(self, strat_payoffs, ori_idx, pvect):
        self.size = strat_payoffs.shape[0]
        self.payoffs = strat_payoffs
        self.strat_idx = ori_idx
        self.probability = pvect
        
    def computeRPS(self):
        return None
    
def solve_MaxEnt_NE(payoff, verbose = False, eps = 1e-5, zero_tol = 1e-6, iters = 500, cycle = 5):
    
    init_val = np.random.uniform(size = payoff.shape[0])
    init_val = init_val / np.sum(init_val)
    
    p = cp.Variable(payoff.shape[0], value = init_val)
    constraints = [payoff @ p <= 0, cp.sum(p) == 1, p >= 0]
    objective = cp.sum(cp.entr(p))
    prob = cp.Problem(cp.Maximize(objective), constraints)
    
    try:
      cycle_count = 0; done = False
      while cycle_count < cycle and done is False:
        prob.solve(verbose = verbose, solver = cp.MOSEK, warm_start = True)
        p_vect = p.value * (p.value > zero_tol)
        diff = payoff @ p_vect.reshape(-1, 1)
        print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
        done = True if np.sum(diff >= eps) == 0 else False
        cycle_count += 1
    except cp.SolverError:
      print("MOSEK FAILED?")
      try:
        # Try ECOS_BB first
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = 1000, solver = cp.ECOS_BB, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
          print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
      except cp.SolverError:
        print("ECOS_BB FAILED")
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = iters, solver = cp.SCS, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
          print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
  
    # Clean - small values
    p_vect = p_vect * (p_vect > zero_tol)
    return p_vect, np.sum(diff>=eps)
    
def Nash_Clustering(payoff, marker, algo = "cvx", eps = 1e-4, zero_tol = 1e-8):
    n_strat = payoff.shape[0]; counter = 0;

    # This is the remaining payoff and the remaining strategy indexes
    curr_payoff = payoff; curr_remaining = np.arange(n_strat); curr_marker = marker
    nash_clusters = []; unsolved_cases = []; marker_instances = []

    while n_strat > 1: # if only 1 strategy remaining, this itself is the nash cluster
        print(f"Iteration {counter}")

        # # Compute the NE supports. Lemke Howson seems the fastest
        # game = nash.Game(curr_payoff + np.eye(curr_payoff.shape[0]) * 1e-10)
        # if algo == "Lemke":
        #     nash_eqs = game.lemke_howson_enumeration()
        #     nash_eq = np.array(next(nash_eqs)[0])

        # if algo == 'Support': # slow because enumerates all possible NE supports
        #     nash_eqs = game.support_enumeration()
        #     nash_eq = np.array(next(nash_eqs)[0])

        # if algo == 'Vertex':
        #     nash_eqs = game.vertex_enumeration()
        #     nash_eq = np.array(next(nash_eqs)[0])

        if algo == 'cvx': # solve using cvxpy, seems to be the only one working for now
            nash_eq, diff = solve_MaxEnt_NE(curr_payoff, eps =1e-4, zero_tol = zero_tol, iters = int(2e4), cycle = 5)
            print(f"Outside, diff = {diff}")
            p_vect = nash_eq[nash_eq >= zero_tol]
#             if diff > -10:
#               print("APPENDING UNSOLVED CASE")
#               unsolved_cases.append(curr_payoff)
#               marker_instances.append(curr_marker)

        # Take the supports, exclude them in the next round payoffs
        taken_strat = np.where(nash_eq >= zero_tol)[0]; remaining_strat = np.where(nash_eq < zero_tol)[0]
        
        if len(taken_strat) != len(p_vect):
            print("WTF")
            print(taken_strat, p_vect)
        taken_idx = np.array(list(itertools.product(taken_strat, repeat = 2)))
        remaining_idx = np.array(list(itertools.product(remaining_strat, repeat = 2)))

        strat_payoffs = payoff[taken_idx[:,0], taken_idx[:, 1]].reshape(taken_strat.shape[0], taken_strat.shape[0])
        nash_clusters.append(NashCluster(strat_payoffs, curr_remaining[taken_strat], p_vect))

        # Get the remaining payoff. If statement here to prevent cases when remaining_idx is empty and [:,0] wont work
        if len(remaining_strat) > 0:
          curr_payoff = curr_payoff[remaining_idx[:,0], remaining_idx[:,1]].reshape(remaining_strat.shape[0], remaining_strat.shape[0])
          curr_remaining = curr_remaining[remaining_strat]
          curr_marker = curr_marker[remaining_idx[:,0], remaining_idx[:,1]].reshape(remaining_strat.shape[0], remaining_strat.shape[0])

        n_strat -= strat_payoffs.shape[0]

        counter += 1
        print(f"Strategies left {n_strat}")
        print(f"Payoff remaining size {curr_payoff.shape[0]}") 

    if n_strat == 1:
        nash_clusters.append(NashCluster(curr_payoff, curr_remaining, np.array([1])))

    return nash_clusters, marker_instances, unsolved_cases

def plot_results(nash_clusters, title):
  nc_sizes = []
  for nc in nash_clusters:
      nc_sizes.append(nc.size)

  y_ax = np.linspace(1, 0, len(nc_sizes))
  plt.scatter(nc_sizes, y_ax)
  plt.title(title)
  plt.ylabel('Fraction Beaten')
  plt.xlabel('Cluster Size')

def compute_RPP(nc1, nc2, payoff):
    p_vect1 = np.zeros(payoff.shape[0]); p_vect2 = np.zeros(payoff.shape[0])
    
    p_vect1[nc1.strat_idx] = nc1.probability; p_vect2[nc2.strat_idx] = nc2.probability
    return (p_vect1.reshape(1, -1) @ payoff @ p_vect2.reshape(-1, 1)).item()
    
def generate_RPP_data(nash_clusters, payoff):
    data_tuples_rpp = []; n_nc = len(nash_clusters); data_tuples_rpp_sign = []; rpp_mat = np.zeros((n_nc, n_nc))
    for i, nc_i in enumerate(nash_clusters):
        rpp_sum = 0; rpp_sign_sum = 0
        for j, nc_j in enumerate(nash_clusters):
            if i != j:
                rpp = compute_RPP(nc_i, nc_j, payoff)
                rpp_mat[i,j] = rpp
                rpp_sum += rpp
                rpp_sign_sum += 1 * (rpp >= 0)

        rpp_sum = rpp_sum / n_nc; rpp_sign_sum = rpp_sign_sum / (n_nc - 1)

        data_tuples_rpp.append([nc_i.size, rpp_sum])
        data_tuples_rpp_sign.append([nc_i.size, rpp_sign_sum])

    return np.array(data_tuples_rpp), np.array(data_tuples_rpp_sign), rpp_mat

def generate_RPS_data(payoff):
    signed_payoff = 1 * (payoff > 0)
    strat_winrate = np.mean(payoff > 0, axis = 1)
    adj = signed_payoff @ signed_payoff @ signed_payoff
    
    return np.diag(adj), strat_winrate

def plot_RPS(adj, strat_winrate, title):
    plt.title(title)
    plt.xlabel('RPS Cycles')
    plt.ylabel('Mean Win-Rate')
    plt.scatter(adj, strat_winrate)
    
def plot_nash_clusters_2(sign_rpp, title):
    plt.scatter(sign_rpp[:, 0], sign_rpp[:, 1])
    plt.title(title)
    plt.ylabel('Fraction Beaten (RPP)')
    plt.xlabel('Cluster Size')
    
def plot_nash_clusters_3(sign_rpp, title, seed = 88):
    plt.scatter(sign_rpp[:, 0], sign_rpp[:, 1])
    plt.title(title)
    plt.ylabel('Fraction Beaten (RPP)')
    plt.xlabel('Cluster Size')
    
    # Fit skewed normal
    np.random.seed(seed)
    y_data = sign_rpp[:, 0]; x_data = sign_rpp[:, 1]
    init = np.random.uniform(1, 3, size = (5))
    params = fit_skewed_normal(init, x_data, y_data)
    
    inputs = np.linspace(0, 1, 1000)
    outputs = affine_skewed_normal_pdf(params, inputs)
    plt.plot(outputs, inputs)
    
    return params
    
# Test using scipy.optimize.minimize. Need a function to minimize with signature function(x, *args), where x is a list
# of the parameters to optimize. Syntax: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize
def affine_skewed_normal_loss(parameters, xdata, ydata):
    """
    parameters shape is [\mu, \sigma, \alpha, \a, \b]
    """
    mu, sigma, alpha, a, b = parameters
    
    # Compute the loss
    out = a * (sigma ** 2) * skewnorm.pdf(xdata, alpha, mu, sigma**2) + b
#     out = a * skewnorm.pdf(xdata, alpha, mu, sigma) + b
    loss = np.sum((out - ydata) ** 2)
    
    return loss

def affine_skewed_normal_pdf(parameters, xdata):
    mu, sigma, alpha, a, b = parameters
    out = a * (sigma ** 2) * skewnorm.pdf(xdata, alpha, mu, sigma**2) + b
#     out = a * skewnorm.pdf(xdata, alpha, mu, sigma) + b
    return out

def fit_skewed_normal(init, xdata, ydata):
    bnds = [(None, None), (1e-15, None), (None, None), (None, None), (None, None)]
    results = minimize(affine_skewed_normal_loss, init, args = (xdata, ydata), bounds = bnds, tol = 1e-8)
    return results.x

def savePickle(var, name):
    with open(name+'.pickle', 'wb') as handle:
        pickle.dump(var, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
def openPickle(name):
    filename = name+'.pickle'
    with open(filename,'rb') as f:
        var = pickle.load(f)
    return var

def generate_elo_nc_data(nash_clusters, lower_bound, upper_bound, n):
    bins = create_bins(lower_bound, upper_bound, n)
    mid_bins = np.mean(np.array(bins), axis = 1)
    data = []
    
    for nc in nash_clusters:
        ori_idx = nc.strat_idx
        av_elo = np.mean(mid_bins[ori_idx])
        data.append([nc.size, av_elo])
    
    return np.array(data)

def plot_elo_nc(data, title):
    plt.title(title)
    plt.xlabel('Nash Cluster Size')
    plt.ylabel('Average Elo')
    plt.scatter(data[:,0], data[:, 1])
    
def compute_win_rate(curr_idx, payoff):
    return np.mean(payoff[curr_idx, :])

# %%
bins = create_bins(750, 3000, 1500)
bins = np.array(bins)
adj = 1 * (payoff > 0)
x = np.diag(adj @ adj @ adj)
y = np.mean(bins, axis = 1)
plt.scatter(x, y)

# %%
elo_nc_data = generate_elo_nc_data(nash_clusters, 750, 2950, 1500)
plot_elo_nc(elo_nc_data, title)

# %%
print(cp.installed_solvers())
# Out:
# ['CVXOPT', 'ECOS', 'ECOS_BB', 'GLPK', 'GLPK_MI', 'MOSEK', 'OSQP', 'SCS']

# %% [markdown]
# ### Chess 1000 x 1000

# %%
# Note: 1st saved matrix is from 800 - 2500
# 2nd saved is 800 - 2800
# 3rd saved is 800 - 2650
# 5 saved is 950 - 2700
# 6 saved is 900 - 2750
# 7 saved is 850 - 2750
# 8 saved is 800 - 2750
# 9: 750 - 2800
# 10: 750 - 2850
# 11: 750 - 2900
# 12: 750 - 2950
# 12.2: 750 - 3050
# 12.3: 750 - 3000

# %%
title = 'Chess 1500 (2020)'

# %%
# If using downloaded payoff, load with this
payoff = openPickle('Data/2020/ChessPayoff12 1500')
markers = openPickle('Data/2020/ChessMarkers12 1500')

# %%
payoff, markers = create_payoff(1500, 750, 2950)
where_zeros = np.where(np.abs(payoff) <= 1e-7)
payoff[where_zeros[0], where_zeros[1]] = 0
# Out:
# 100%|██████████| 1500/1500 [8:34:42<00:00, 20.59s/it]

# %%
nash_clusters, markers_instances, unsolved_cases = Nash_Clustering(payoff, markers)
# Out:
# Iteration 0
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1494
# Payoff remaining size 1494
# Iteration 1
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1486
# Payoff remaining size 1486
# Iteration 2
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1478
# Payoff remaining size 1478
# Iteration 3
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1473
# Payoff remaining size 1473
# Iteration 4
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1467
# Payoff remaining size 1467
# Iteration 5
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1460
# Payoff remaining size 1460
# Iteration 6
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1455
# Payoff remaining size 1455
# Iteration 7
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1450
# Payoff remaining size 1450
# Iteration 8
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1449
# Payoff remaining size 1449
# Iteration 9
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1436
# Payoff remaining size 1436
# Iteration 10
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1427
# Payoff remaining size 1427
# Iteration 11
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1420
# Payoff remaining size 1420
# Iteration 12
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1411
# Payoff remaining size 1411
# Iteration 13
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1400
# Payoff remaining size 1400
# Iteration 14
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1385
# Payoff remaining size 1385
# Iteration 15
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1373
# Payoff remaining size 1373
# Iteration 16
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1365
# Payoff remaining size 1365
# Iteration 17
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1356
# Payoff remaining size 1356
# Iteration 18
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1344
# Payoff remaining size 1344
# Iteration 19
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1336
# Payoff remaining size 1336
# Iteration 20
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1319
# Payoff remaining size 1319
# Iteration 21
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1309
# Payoff remaining size 1309
# Iteration 22
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1293
# Payoff remaining size 1293
# Iteration 23
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1281
# Payoff remaining size 1281
# Iteration 24
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1269
# Payoff remaining size 1269
# Iteration 25
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1254
# Payoff remaining size 1254
# Iteration 26
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1240
# Payoff remaining size 1240
# Iteration 27
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1225
# Payoff remaining size 1225
# Iteration 28
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1208
# Payoff remaining size 1208
# Iteration 29
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1187
# Payoff remaining size 1187
# Iteration 30
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1168
# Payoff remaining size 1168
# Iteration 31
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1152
# Payoff remaining size 1152
# Iteration 32
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1132
# Payoff remaining size 1132
# Iteration 33
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1116
# Payoff remaining size 1116
# Iteration 34
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1097
# Payoff remaining size 1097
# Iteration 35
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1075
# Payoff remaining size 1075
# Iteration 36
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1054
# Payoff remaining size 1054
# Iteration 37
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1029
# Payoff remaining size 1029
# Iteration 38
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1010
# Payoff remaining size 1010
# Iteration 39
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 991
# Payoff remaining size 991
# Iteration 40
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 975
# Payoff remaining size 975
# Iteration 41
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 954
# Payoff remaining size 954
# Iteration 42
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 932
# Payoff remaining size 932
# Iteration 43
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 916
# Payoff remaining size 916
# Iteration 44
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 892
# Payoff remaining size 892
# Iteration 45
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 865
# Payoff remaining size 865
# Iteration 46
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 851
# Payoff remaining size 851
# Iteration 47
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 830
# Payoff remaining size 830
# Iteration 48
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 807
# Payoff remaining size 807
# Iteration 49
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 790
# Payoff remaining size 790
# Iteration 50
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 769
# Payoff remaining size 769
# Iteration 51
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 730
# Payoff remaining size 730
# Iteration 52
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 707
# Payoff remaining size 707
# Iteration 53
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 684
# Payoff remaining size 684
# Iteration 54
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 661
# Payoff remaining size 661
# Iteration 55
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 642
# Payoff remaining size 642
# Iteration 56
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 614
# Payoff remaining size 614
# Iteration 57
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 594
# Payoff remaining size 594
# Iteration 58
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 574
# Payoff remaining size 574
# Iteration 59
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 543
# Payoff remaining size 543
# Iteration 60
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 523
# Payoff remaining size 523
# Iteration 61
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 501
# Payoff remaining size 501
# Iteration 62
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 478
# Payoff remaining size 478
# Iteration 63
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 455
# Payoff remaining size 455
# Iteration 64
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 431
# Payoff remaining size 431
# Iteration 65
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 414
# Payoff remaining size 414
# Iteration 66
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 387
# Payoff remaining size 387
# Iteration 67
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 360
# Payoff remaining size 360
# Iteration 68
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 344
# Payoff remaining size 344
# Iteration 69
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 327
# Payoff remaining size 327
# Iteration 70
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 304
# Payoff remaining size 304
# Iteration 71
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 286
# Payoff remaining size 286
# Iteration 72
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 259
# Payoff remaining size 259
# Iteration 73
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 239
# Payoff remaining size 239
# Iteration 74
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 216
# Payoff remaining size 216
# Iteration 75
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 191
# Payoff remaining size 191
# Iteration 76
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 174
# Payoff remaining size 174
# Iteration 77
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 156
# Payoff remaining size 156
# Iteration 78
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 137
# Payoff remaining size 137
# Iteration 79
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 111
# Payoff remaining size 111
# Iteration 80
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 95
# Payoff remaining size 95
# Iteration 81
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 78
# Payoff remaining size 78
# Iteration 82
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 54
# Payoff remaining size 54
# Iteration 83
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 34
# Payoff remaining size 34
# Iteration 84
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 20
# Payoff remaining size 20
# Iteration 85
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 18
# Payoff remaining size 18
# Iteration 86
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 14
# Payoff remaining size 14
# Iteration 87
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 6
# Payoff remaining size 6
# Iteration 88
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 5
# Payoff remaining size 5
# Iteration 89
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 4
# Payoff remaining size 4
# Iteration 90
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 3
# Payoff remaining size 3
# Iteration 91
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 2
# Payoff remaining size 2
# Iteration 92
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 1
# Payoff remaining size 1

# %%
rpp_tuples, rpp_sign_tuples, rpp_mat = generate_RPP_data(nash_clusters, payoff)
adj, strat_winrate = generate_RPS_data(payoff)
plot_RPS(adj, strat_winrate, title)

# %%
y_data = rpp_sign_tuples[:, 0]; x_data = rpp_sign_tuples[:, 1]
np.random.seed(888)
init = np.random.uniform(1, 3, size = (5))
print(init)
params = fit_skewed_normal(init, x_data, y_data)
print(params)
# Out:
# [2.71912121 1.32913899 1.96695192 2.84205453 1.85711288]
# [ 4.45299491e-01  5.80680371e-01 -3.52339782e-03  7.12149636e+01
#  -4.49308145e+00]

# %%
seed = 888
params = plot_nash_clusters_3(rpp_sign_tuples, title, seed)

# %%
savePickle(params, '2020 NC Plot Params 1500 12')
savePickle(nash_clusters, '2020 Nash Clusters 1500 12')
savePickle(rpp_sign_tuples, '2020 rpp sign tuples 1500 12')
savePickle(rpp_tuples, '2020 rpp tuples 1500 12')
savePickle(rpp_mat, '2020 rpp mat 1500 12')

# %%
plt.figure(figsize = (15,8))
plt.title(title)
sb.heatmap(rpp_mat, cmap = 'RdBu', xticklabels = False, yticklabels = False, annot = False)
# Out:
# <AxesSubplot:title={'center':'Chess 1000 (2020)'}>

# %%
savePickle(payoff, 'Data/2020/ChessPayoff12,2 1500')
savePickle(markers, 'Data/2020/ChessMarkers12,2 1500')

# %% [markdown]
# ### Histogram Data Extraction

# %%
year = 2020
elos = np.concatenate([white_elos, black_elos])
bins = create_bins(750, 2950, 100)
bins = np.array(bins)
hist_bins = np.concatenate([bins[:, 0], [2950]])
plt.title(title + ' Elo Histogram')
out = plt.hist(elos, bins = hist_bins)

# %%
# Data to reproduce plots
counts = out[0]; act_counts = counts
mid_bins = np.mean(bins, axis = 1)
counts = counts / np.sum(counts)
plt.scatter(mid_bins, counts)
set_data = [mid_bins, counts]
count_data = [mid_bins, act_counts]
# savePickle(set_data, 'Data/'+ str(year)+ '/Histogram Data')

# %%
# Fit skewed normal
plt.scatter(counts, mid_bins)
seed = 888
np.random.seed(seed)
y_data = counts; x_data = mid_bins
init = np.random.uniform(0, 0.5, size = (5))
init[0] = 1500; init[1] = 10 * np.sqrt(2)
params = fit_skewed_normal(init, x_data, y_data)

inputs = np.linspace(750, 2950, 1500)
outputs = affine_skewed_normal_pdf(params, inputs)
plt.plot(outputs, inputs)

# %%
# Save fitted params so no need to repeat
savePickle(params, 'Data/'+str(year)+'/Histogram Param')
savePickle(set_data, 'Data/'+ str(year)+ '/Histogram Data')
savePickle(elos, 'Data/'+str(year)+'/Histogram Elos')
savePickle(count_data, 'Data/'+str(year)+'/Histogram Count Data')

# %% [markdown]
# ### Training Data Extraction

# %%
# With Uniform

def compute_win_rate(curr_idx, payoff):
    return np.mean(payoff[curr_idx, :])

def generate_training_data(payoff, pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300, 350]):
    win_rates_results = dict()

    for pop_size in pop_sizes:
        print(f"Population Size {pop_size}")
        win_rates = []
        strat_strengths = np.mean(payoff > 0, axis = 1)
        ordering_idx = np.argsort(strat_strengths)

        curr_strat_idx = list(ordering_idx[:pop_size])
        win_rates.append(compute_win_rate(curr_strat_idx, payoff))
        n_iters = 2000; it = 0
        converge = False
        while it < n_iters:
            taken_payoff = np.sum(payoff[:, curr_strat_idx], axis = 1)
            viable_strats = np.where(taken_payoff > 0)[0]
            not_in = ~np.isin(viable_strats, curr_strat_idx)
            viable_strats = viable_strats[not_in]
            if len(viable_strats) > 0:
                viable_strengths = strat_strengths[viable_strats]
                sorted_idx = np.argsort(viable_strengths)
                new_strat = viable_strats[sorted_idx[0]]
                curr_strat_idx.append(new_strat)
                curr_strat_idx = curr_strat_idx[1:]
            else:
                if converge == False:
                    converge = True
                    it_conv = it
                    print(f"First Reached Peak at {it_conv}")


            win_rates.append(compute_win_rate(curr_strat_idx, payoff))
            it += 1

        if converge == False:
            print(f"Population size {pop_size} doesn't converge")
            
        win_rates_results[pop_size] = win_rates
    
    return win_rates_results

def plot_training(win_rates_results, title, save = False):
    plt.figure(figsize = (10,8))
    plt.title(title)
    for pop_size in win_rates_results.keys():
        win_rates = win_rates_results[pop_size]
        plt.plot(np.arange(len(win_rates)), win_rates, label = str(pop_size))
        
    plt.xlabel('Iterations')
    plt.ylabel('Mean Win Rate')
    plt.legend(title = 'Population Size')
    
    if save:
        plt.savefig('Training Plots.pdf')

# %%
payoff = openPickle('Data/2020/ChessPayoff12 1500')

# %%
pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300]
training_performances = generate_training_data(payoff, pop_sizes)
# Out:
# Population Size 1
# Population size 1 doesn't converge
# Population Size 25
# Population size 25 doesn't converge
# Population Size 50
# First Reached Peak at 1567
# Population Size 75
# First Reached Peak at 1429
# Population Size 100
# First Reached Peak at 1400
# Population Size 150
# First Reached Peak at 1350
# Population Size 200
# First Reached Peak at 1300
# Population Size 250
# First Reached Peak at 1250
# Population Size 300
# First Reached Peak at 1200

# %%
plot_training(training_performances, 'Lichess 2020')

# %%
savePickle(training_performances, 'Lichess 2020 Training Uniform')

# %%
# With Nash
def compute_win_rate(curr_idx, payoff):
    return np.mean(payoff[curr_idx, :])

def compute_win_rate3(curr_strat_idx, payoff):
    # With Nash
    pop_size = len(curr_strat_idx)
    taken_idx = np.array(list(itertools.product(curr_strat_idx, repeat = 2)))
    taken_payoff = payoff[taken_idx[:, 0], taken_idx[:, 1]].reshape(pop_size, pop_size)
    p_vect, _ = solve_MaxEnt_NE(taken_payoff)
    prob_vect = np.zeros((payoff.shape[0]))
    prob_vect[curr_strat_idx] = p_vect
    return np.mean(prob_vect.reshape(1, -1) @ payoff)

def generate_training_data3(payoff, pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300, 350]):
    win_rates_results = dict()

    for pop_size in pop_sizes:
        print(f"Population Size {pop_size}")
        win_rates = []
        strat_strengths = np.mean(payoff > 0, axis = 1)
        ordering_idx = np.argsort(strat_strengths)

        curr_strat_idx = list(ordering_idx[:pop_size])
        if pop_size == 1:
            win_rates.append(compute_win_rate(curr_strat_idx, payoff))
        else:
            win_rates.append(compute_win_rate3(curr_strat_idx, payoff))
        n_iters = 2000; it = 0
        converge = False; prev_win_rate = 0
        while it < n_iters:
            taken_payoff = np.sum(payoff[:, curr_strat_idx], axis = 1)
            viable_strats = np.where(taken_payoff > 0)[0]
            not_in = ~np.isin(viable_strats, curr_strat_idx)
            viable_strats = viable_strats[not_in]
            if len(viable_strats) > 0:
                viable_strengths = strat_strengths[viable_strats]
                sorted_idx = np.argsort(viable_strengths)
                new_strat = viable_strats[sorted_idx[0]]
                curr_strat_idx.append(new_strat)
                curr_strat_idx = curr_strat_idx[1:]
            else:
                if converge == False:
                    converge = True
                    it_conv = it
                    print(f"First Reached Peak at {it_conv}")

            if pop_size == 1:
                win_rates.append(compute_win_rate(curr_strat_idx, payoff))
            else:
                if converge:
                    win_rates.append(prev_win_rate)
                else:
                    prev_win_rate = compute_win_rate3(curr_strat_idx, payoff)
                    win_rates.append(prev_win_rate)
                    
            it += 1

        if converge == False:
            print(f"Population size {pop_size} doesn't converge")
            
        win_rates_results[pop_size] = win_rates
    
    return win_rates_results

def solve_MaxEnt_NE(payoff, verbose = False, eps = 1e-5, zero_tol = 1e-6, iters = 500, cycle = 5):
    
    init_val = np.random.uniform(size = payoff.shape[0])
    init_val = init_val / np.sum(init_val)
    
    p = cp.Variable(payoff.shape[0], value = init_val)
    constraints = [payoff @ p <= 0, cp.sum(p) == 1, p >= 0]
    objective = cp.sum(cp.entr(p))
    prob = cp.Problem(cp.Maximize(objective), constraints)
    
    try:
      cycle_count = 0; done = False
      while cycle_count < cycle and done is False:
        prob.solve(verbose = verbose, solver = cp.MOSEK, warm_start = True)
        p_vect = p.value * (p.value > zero_tol)
        diff = payoff @ p_vect.reshape(-1, 1)
#         print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
        done = True if np.sum(diff >= eps) == 0 else False
        cycle_count += 1
    except cp.SolverError:
      print("MOSEK FAILED?")
      try:
        # Try ECOS_BB first
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = 1000, solver = cp.ECOS_BB, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
#           print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
      except cp.SolverError:
        print("ECOS_BB FAILED")
        cycle_count = 0; done = False
        while cycle_count < cycle and done is False:
          prob.solve(verbose = verbose, max_iters = iters, solver = cp.SCS, warm_start = True)
          p_vect = p.value * (p.value > zero_tol)
          diff = payoff @ p_vect.reshape(-1, 1)
#           print(f"Cycle count {cycle_count}, diff = {np.sum(diff >= eps)}")
          done = True if np.sum(diff >= eps) == 0 else False
          cycle_count += 1
  
    # Clean - small values
    p_vect = p_vect * (p_vect > zero_tol)
    return p_vect, np.sum(diff>=eps)

# %%
pop_sizes = [1, 25, 50, 75, 100, 150, 200, 250, 300]
training_performances_nash = generate_training_data3(payoff, pop_sizes)
# Out:
# Population Size 1
# Population size 1 doesn't converge
# Population Size 25
# Population size 25 doesn't converge
# Population Size 50
# First Reached Peak at 1567
# Population Size 75
# First Reached Peak at 1429
# Population Size 100
# First Reached Peak at 1400
# Population Size 150
# First Reached Peak at 1350
# Population Size 200
# First Reached Peak at 1300
# Population Size 250
# MOSEK FAILED?
# C:\ProgramData\Anaconda3\lib\site-packages\cvxpy\problems\problem.py:1278: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# First Reached Peak at 1250
# Population Size 300
# First Reached Peak at 1200

# %%
plot_training(training_performances_nash, 'Lichess 2020')

# %%
savePickle(training_performances_nash, 'Lichess 2020 Training Nash')

# %%
payoff_1= np.array([[3, -1], [-2, 1]])
payoff_2 = np.array([[-3, 1], [2, -1]])
verbose = True

lp1 = payoff_1.shape[0]
lp2 = payoff_1.shape[1]

init_value = np.random.normal(size = lp1)
init_value = init_value / np.sum(init_value)
p1 = cp.Variable(lp1, value = init_value)
z = cp.Variable(1)
constraints = [cp.reshape(p1, (1, lp1)) @ payoff_1 >= z, cp.sum(p1) == 1, p1 >= 0]
problem = cp.Problem(cp.Maximize(z), constraints)

problem.solve(solver = cp.MOSEK, verbose = verbose)
print(p1.value)

init_value = np.random.normal(size = lp2)
init_value = init_value / np.sum(init_value)
p2 = cp.Variable(lp2, value = init_value)
z = cp.Variable(1)
constraints = [payoff_2 @ cp.reshape(p2, (lp2, 1)) >= z, cp.sum(p2) == 1, p2 >= 0]
problem = cp.Problem(cp.Maximize(z), constraints)

problem.solve(solver = cp.MOSEK, verbose = verbose)
print(p2.value)
# Out:
# ===============================================================================
#                                      CVXPY
#                                     v1.1.13
# ===============================================================================
# (CVXPY) Aug 22 04:04:24 PM: Your problem has 3 variables, 3 constraints, and 0 parameters.
# (CVXPY) Aug 22 04:04:24 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 04:04:24 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 04:04:24 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:04:24 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 04:04:24 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction FlipObjective
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 04:04:24 PM: Finished problem compilation (took 6.981e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:04:24 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 3
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 3
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 3                 conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1                 after factor           : 1
# Factor     - dense dim.             : 0                 flops                  : 7.00e+00
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   3.8e+00  1.1e+01  1.8e+00  0.00e+00   -6.457513111e-01  -1.000000000e+00  8.0e+00  0.00
# 1   6.4e-01  1.9e+00  3.1e-01  1.95e-01   5.029049962e-01   3.064525350e-01   1.4e+00  0.00
# 2   5.8e-02  1.7e-01  2.8e-02  9.67e-01   -6.538440191e-02  -7.044938442e-02  1.2e-01  0.00
# 3   6.9e-05  2.1e-04  3.3e-05  1.09e+00   -1.428251328e-01  -1.428370530e-01  1.5e-04  0.00
# 4   6.9e-09  2.1e-08  3.3e-09  1.00e+00   -1.428571397e-01  -1.428571408e-01  1.5e-08  0.00
# 5   6.9e-13  2.1e-12  3.3e-13  1.00e+00   -1.428571429e-01  -1.428571429e-01  1.5e-12  0.00
# Optimizer terminated. Time: 0.02
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -1.4285714286e-01   nrm: 1e+00    Viol.  con: 2e-12    var: 0e+00
#   Dual.    obj: -1.4285714286e-01   nrm: 6e-01    Viol.  con: 0e+00    var: 9e-13
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:04:24 PM: Problem status: optimal
# (CVXPY) Aug 22 04:04:24 PM: Optimal value: 1.429e-01
# (CVXPY) Aug 22 04:04:24 PM: Compilation took 6.981e-03 seconds
# (CVXPY) Aug 22 04:04:24 PM: Solver (including time spent in interface) took 3.092e-02 seconds
# [0.42857143 0.57142857]
# ===============================================================================
#                                      CVXPY
#                                     v1.1.13
# ===============================================================================
# (CVXPY) Aug 22 04:04:24 PM: Your problem has 3 variables, 3 constraints, and 0 parameters.
# (CVXPY) Aug 22 04:04:24 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 04:04:24 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 04:04:24 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:04:24 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 04:04:24 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction FlipObjective
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 04:04:24 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 04:04:24 PM: Finished problem compilation (took 5.984e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:04:24 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 3
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 3
#   Cones                  : 0
#   Scalar variables       : 5
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 3                 conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1                 after factor           : 1
# Factor     - dense dim.             : 0                 flops                  : 7.00e+00
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.7e+00  4.4e+00  1.5e+01  0.00e+00   -3.645751311e+00  1.000000000e+00   7.3e+00  0.00
# 1   2.6e-01  4.3e-01  1.5e+00  3.46e-01   1.099325142e-01   6.743321020e-01   7.1e-01  0.00
# 2   9.4e-03  1.6e-02  5.3e-02  1.11e+00   1.344613260e-01   1.538303330e-01   2.5e-02  0.00
# 3   1.2e-06  2.0e-06  7.0e-06  1.01e+00   1.428558095e-01   1.428582596e-01   3.3e-06  0.00
# 4   1.2e-10  2.0e-10  7.0e-10  1.00e+00   1.428571427e-01   1.428571430e-01   3.3e-10  0.00
# 5   1.2e-14  1.9e-14  5.8e-14  1.00e+00   1.428571429e-01   1.428571429e-01   3.3e-14  0.00
# Optimizer terminated. Time: 0.02
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.4285714286e-01    nrm: 1e+00    Viol.  con: 2e-14    var: 0e+00
#   Dual.    obj: 1.4285714286e-01    nrm: 7e-01    Viol.  con: 0e+00    var: 9e-18
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:04:24 PM: Problem status: optimal
# (CVXPY) Aug 22 04:04:24 PM: Optimal value: -1.429e-01
# (CVXPY) Aug 22 04:04:24 PM: Compilation took 5.984e-03 seconds
# (CVXPY) Aug 22 04:04:24 PM: Solver (including time spent in interface) took 3.092e-02 seconds
# [0.28571429 0.71428571]

# %%
print(p1.value)
print(p2.value)
# Out:
# [0.42857143 0.57142857]
# [0.28571429 0.71428571]

# %%
nash_clusters = openPickle('Data/2020/2020 Nash Clusters 1500 12')
payoff = openPickle('Data/2020/ChessPayoff12,2 1500')

# %%
A = 1 * (payoff > 0)
cycles = A @ A @ A @ A @ A
cycles = np.diag(cycles)

# %%
winrates = np.sum(A, axis = 1) / (A.shape[1] - 1)
plt.scatter(cycles, winrates)

# %%
def solve_NE_alt(payoff_1, payoff_2, verbose):
    lp1 = payoff_1.shape[0]
    lp2 = payoff_1.shape[1]

    init_value = np.random.normal(size = lp1)
    init_value = init_value / np.sum(init_value)
    p1 = cp.Variable(lp1, value = init_value)
    z = cp.Variable(1)
    constraints = [cp.reshape(p1, (1, lp1)) @ payoff_1 >= z, cp.sum(p1) == 1, p1 >= 0]
    problem = cp.Problem(cp.Maximize(z), constraints)

    problem.solve(solver = cp.MOSEK, verbose = verbose)

    init_value = np.random.normal(size = lp2)
    init_value = init_value / np.sum(init_value)
    p2 = cp.Variable(lp2, value = init_value)
    z = cp.Variable(1)
    constraints = [payoff_2 @ cp.reshape(p2, (lp2, 1)) >= z, cp.sum(p2) == 1, p2 >= 0]
    problem = cp.Problem(cp.Maximize(z), constraints)

    problem.solve(solver = cp.MOSEK, verbose = verbose)
    
    return np.array(p1.value), np.array(p2.value)

def compute_RPP(nc1, nc2, payoff):
    p1_idx = nc1.strat_idx; p2_idx = nc2.strat_idx
    combinations = np.array(list(itertools.product(p1_idx, p2_idx)))
    payoff1 = payoff[combinations[:,0], combinations[:,1]].reshape(len(p1_idx), len(p2_idx))
    payoff2 = -payoff1
    p1, p2 = solve_NE_alt(payoff1, payoff2, False)
    rpp = p1.reshape(1, -1) @ payoff1 @ p2.reshape(-1, 1)
    print(rpp.item())
    
def generate_RPP_data(nash_clusters, payoff):
    data_tuples_rpp = []; n_nc = len(nash_clusters); data_tuples_rpp_sign = []; rpp_mat = np.zeros((n_nc, n_nc))
    for i, nc_i in enumerate(nash_clusters):
        rpp_sum = 0; rpp_sign_sum = 0
        for j, nc_j in enumerate(nash_clusters):
            if i != j:
                rpp = compute_RPP(nc_i, nc_j, payoff)
                rpp_mat[i,j] = rpp
                rpp_sum += rpp
                rpp_sign_sum += 1 * (rpp >= 0)

        rpp_sum = rpp_sum / n_nc; rpp_sign_sum = rpp_sign_sum / (n_nc - 1)

        data_tuples_rpp.append([nc_i.size, rpp_sum])
        data_tuples_rpp_sign.append([nc_i.size, rpp_sign_sum])

    return np.array(data_tuples_rpp), np.array(data_tuples_rpp_sign), rpp_mat

# %%
nc1 = nash_clusters[0]
for j in range(1, len(nash_clusters)):
    nc2 = nash_clusters[j]
    p1_idx = nc1.strat_idx; p2_idx = nc2.strat_idx
    combinations = np.array(list(itertools.product(p1_idx, p2_idx)))

    payoff1 = payoff[combinations[:,0], combinations[:,1]].reshape(len(p1_idx), len(p2_idx))
    payoff2 = -payoff1
    p1, p2 = solve_NE_alt(payoff1, payoff2, False)
    rpp = p1.reshape(1, -1) @ payoff1 @ p2.reshape(-1, 1)
    print(rpp)
# Out:
# [[0.02206286]]
# [[0.04850807]]
# [[0.07488544]]
# [[0.09241461]]
# [[0.11424453]]
# [[0.14029376]]
# [[0.16185563]]
# [[0.59163203]]
# [[0.19178019]]

# %%
len(nash_clusters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5ee25823466> in <module>
# ----> 1 len(nash_clusters)
#
# NameError: name 'nash_clusters' is not defined

# %%
nc1 = nash_clusters[0]; nc2 = nash_clusters[9]
p1_idx = nc1.strat_idx; p2_idx = nc2.strat_idx
combinations = np.array(list(itertools.product(p1_idx, p2_idx)))

payoff1 = payoff[combinations[:,0], combinations[:,1]].reshape(len(p1_idx), len(p2_idx))
payoff2 = -payoff1

# %%
p1, p2 = solve_NE_alt(payoff1, payoff2, True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                     v1.1.13
# ===============================================================================
# (CVXPY) Aug 22 04:22:47 PM: Your problem has 7 variables, 3 constraints, and 0 parameters.
# (CVXPY) Aug 22 04:22:47 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 04:22:47 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 04:22:47 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:22:47 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 04:22:47 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction FlipObjective
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 04:22:47 PM: Finished problem compilation (took 5.983e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:22:47 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 7
#   Cones                  : 0
#   Scalar variables       : 20
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Optimizer terminated. Time: 0.03
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -1.9178018504e-01   nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#   Dual.    obj: -1.9178018504e-01   nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:22:47 PM: Problem status: optimal
# (CVXPY) Aug 22 04:22:47 PM: Optimal value: 1.918e-01
# (CVXPY) Aug 22 04:22:47 PM: Compilation took 5.983e-03 seconds
# (CVXPY) Aug 22 04:22:47 PM: Solver (including time spent in interface) took 3.092e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                     v1.1.13
# ===============================================================================
# (CVXPY) Aug 22 04:22:47 PM: Your problem has 14 variables, 3 constraints, and 0 parameters.
# (CVXPY) Aug 22 04:22:47 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 04:22:47 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 04:22:47 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:22:47 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 04:22:47 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction FlipObjective
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 04:22:47 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 04:22:47 PM: Finished problem compilation (took 6.981e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:22:47 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 14
#   Cones                  : 0
#   Scalar variables       : 20
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 14
#   Cones                  : 0
#   Scalar variables       : 20
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 7
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 21                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 28                after factor           : 28
# Factor     - dense dim.             : 0                 flops                  : 9.64e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.0e+00  2.4e+01  2.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   4.0e+00  0.00
# 1   3.4e-01  4.1e+00  3.4e-01  2.83e+00   1.258917497e-01   1.733489625e-01   6.9e-01  0.00
# 2   6.0e-02  7.2e-01  6.0e-02  1.73e+00   1.962792729e-01   2.027439296e-01   1.2e-01  0.00
# 3   3.7e-03  4.4e-02  3.7e-03  9.91e-01   1.908839858e-01   1.912442365e-01   7.4e-03  0.00
# 4   5.6e-06  6.7e-05  5.6e-06  1.01e+00   1.917805783e-01   1.917811244e-01   1.1e-05  0.00
# 5   5.6e-10  6.7e-09  5.6e-10  1.00e+00   1.917801851e-01   1.917801851e-01   1.1e-09  0.00
# Optimizer terminated. Time: 0.03
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.9178018508e-01    nrm: 1e+00    Viol.  con: 6e-11    var: 4e-11
#   Dual.    obj: 1.9178018513e-01    nrm: 1e+00    Viol.  con: 0e+00    var: 7e-10
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 04:22:47 PM: Problem status: optimal
# (CVXPY) Aug 22 04:22:47 PM: Optimal value: -1.918e-01
# (CVXPY) Aug 22 04:22:47 PM: Compilation took 6.981e-03 seconds
# (CVXPY) Aug 22 04:22:47 PM: Solver (including time spent in interface) took 4.089e-02 seconds

# %%
rpp = p1.reshape(1, -1) @ payoff1 @ p2.reshape(-1, 1)

# %%
rpp
# Out:
# array([[0.19178019]])

# %% [markdown]
# ### Nash Cluster Size Experiment

# %%
results_dict = dict()

# %%
payoff, markers = create_payoff(500, 750, 3000)
# Out:
# 100%|██████████| 500/500 [57:31<00:00,  6.90s/it]

# %%
nash_clusters, markers_instances, unsolved_cases = Nash_Clustering(payoff, markers)
# Out:
# Iteration 0
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 496
# Payoff remaining size 496
# Iteration 1
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 492
# Payoff remaining size 492
# Iteration 2
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 483
# Payoff remaining size 483
# Iteration 3
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 476
# Payoff remaining size 476
# Iteration 4
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 467
# Payoff remaining size 467
# Iteration 5
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 457
# Payoff remaining size 457
# Iteration 6
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 449
# Payoff remaining size 449
# Iteration 7
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 437
# Payoff remaining size 437
# Iteration 8
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 427
# Payoff remaining size 427
# Iteration 9
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 419
# Payoff remaining size 419
# Iteration 10
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 408
# Payoff remaining size 408
# Iteration 11
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 399
# Payoff remaining size 399
# Iteration 12
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 391
# Payoff remaining size 391
# Iteration 13
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 380
# Payoff remaining size 380
# Iteration 14
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 371
# Payoff remaining size 371
# Iteration 15
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 362
# Payoff remaining size 362
# Iteration 16
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 352
# Payoff remaining size 352
# Iteration 17
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 344
# Payoff remaining size 344
# Iteration 18
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 336
# Payoff remaining size 336
# Iteration 19
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 330
# Payoff remaining size 330
# Iteration 20
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 323
# Payoff remaining size 323
# Iteration 21
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 317
# Payoff remaining size 317
# Iteration 22
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 313
# Payoff remaining size 313
# Iteration 23
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 308
# Payoff remaining size 308
# Iteration 24
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 301
# Payoff remaining size 301
# Iteration 25
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 297
# Payoff remaining size 297
# Iteration 26
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 291
# Payoff remaining size 291
# Iteration 27
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 286
# Payoff remaining size 286
# Iteration 28
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 279
# Payoff remaining size 279
# Iteration 29
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 271
# Payoff remaining size 271
# Iteration 30
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 265
# Payoff remaining size 265
# Iteration 31
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 260
# Payoff remaining size 260
# Iteration 32
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 256
# Payoff remaining size 256
# Iteration 33
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 248
# Payoff remaining size 248
# Iteration 34
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 243
# Payoff remaining size 243
# Iteration 35
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 237
# Payoff remaining size 237
# Iteration 36
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 232
# Payoff remaining size 232
# Iteration 37
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 226
# Payoff remaining size 226
# Iteration 38
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 220
# Payoff remaining size 220
# Iteration 39
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 216
# Payoff remaining size 216
# Iteration 40
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 208
# Payoff remaining size 208
# Iteration 41
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 200
# Payoff remaining size 200
# Iteration 42
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 192
# Payoff remaining size 192
# Iteration 43
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 184
# Payoff remaining size 184
# Iteration 44
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 174
# Payoff remaining size 174
# Iteration 45
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 168
# Payoff remaining size 168
# Iteration 46
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 161
# Payoff remaining size 161
# Iteration 47
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 153
# Payoff remaining size 153
# Iteration 48
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 149
# Payoff remaining size 149
# Iteration 49
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 145
# Payoff remaining size 145
# Iteration 50
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 139
# Payoff remaining size 139
# Iteration 51
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 133
# Payoff remaining size 133
# Iteration 52
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 126
# Payoff remaining size 126
# Iteration 53
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 118
# Payoff remaining size 118
# Iteration 54
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 107
# Payoff remaining size 107
# Iteration 55
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 102
# Payoff remaining size 102
# Iteration 56
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 92
# Payoff remaining size 92
# Iteration 57
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 82
# Payoff remaining size 82
# Iteration 58
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 72
# Payoff remaining size 72
# Iteration 59
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 64
# Payoff remaining size 64
# Iteration 60
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 58
# Payoff remaining size 58
# Iteration 61
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 49
# Payoff remaining size 49
# Iteration 62
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 38
# Payoff remaining size 38
# Iteration 63
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 34
# Payoff remaining size 34
# Iteration 64
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 24
# Payoff remaining size 24
# Iteration 65
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 13
# Payoff remaining size 13
# Iteration 66
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 5
# Payoff remaining size 5
# Iteration 67
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 3
# Payoff remaining size 3
# Iteration 68
# Cycle count 0, diff = 0
# Outside, diff = 0
# Strategies left 0
# Payoff remaining size 3

# %%
title = "Lichess 2020 500 x 500"
rpp_tuples, rpp_sign_tuples, rpp_mat = generate_RPP_data(nash_clusters, payoff)
adj, strat_winrate = generate_RPS_data(payoff)
plot_RPS(adj, strat_winrate, title)

# %%
seed = 0
params = plot_nash_clusters_3(rpp_sign_tuples, title, seed)

# %%
results_dict[500] = [payoff, nash_clusters]
